# %%
pip install phe

# %%
import os
import sys
import time
import numpy as np
import copy
from concurrent.futures import ProcessPoolExecutor
import multiprocessing
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc
import matplotlib.pyplot as plt
import pandas as pd

# ============================================================
# 1. AUTO-GENERATE WORKER FILE (Fixes Jupyter Multiprocessing)
# ============================================================
worker_script = """
import math
import numpy as np
from phe import paillier

class MockCiphertext:
    def __init__(self, value): self.value = value
    def __add__(self, other): return MockCiphertext(self.value + other.value)
    def __mul__(self, other): return MockCiphertext(self.value * other)

class MockKey:
    def encrypt(self, value): return MockCiphertext(value)
    def decrypt(self, ciphertext): return ciphertext.value

def _safe_encrypt_int(pub_key, value, max_retries=16):
    if not hasattr(pub_key, 'nsquare'):
        return pub_key.encrypt(int(value))
    for _ in range(max_retries):
        enc = pub_key.encrypt(int(value))
        if math.gcd(int(enc.ciphertext(False)), int(pub_key.nsquare)) == 1:
            return enc
    raise ZeroDivisionError('Failed to sample an invertible Paillier ciphertext')

def _encrypt_chunk(args):
    pub_key, chunk = args
    return [_safe_encrypt_int(pub_key, x) for x in chunk]

def _decrypt_chunk(args):
    priv_key, chunk = args
    return [priv_key.decrypt(x) for x in chunk]

def _calc_score_worker(args):
    enc_chunk, ref_int_chunk = args
    if len(enc_chunk) == 0:
        return 0
    partial_sum = enc_chunk[0] * ref_int_chunk[0]
    for i in range(1, len(enc_chunk)):
        partial_sum = partial_sum + (enc_chunk[i] * ref_int_chunk[i])
    return partial_sum

def _train_client_worker(args):
    c_id, X, y, W_init, b_init, is_malicious, num_classes, input_dim, pub_key, scale, lr, batch, epochs = args

    W = W_init.copy()
    b = b_init.copy()
    prev_W = W.copy()
    prev_b = b.copy()
    y_train = y.copy()

    if is_malicious:
        # TARGETED LABEL FLIPPING ATTACK: class 1 -> class 7
        y_train[y_train == 1] = 7

    indices = np.arange(len(X))

    def softmax(z):
        exp_z = np.exp(z - np.max(z, axis=1, keepdims=True))
        return exp_z / exp_z.sum(axis=1, keepdims=True)

    for _ in range(epochs):
        np.random.shuffle(indices)
        for start in range(0, len(X), batch):
            end = start + batch
            idx = indices[start:end]
            if len(idx) == 0:
                continue

            X_b, y_b = X[idx], y_train[idx]
            scores = np.dot(X_b, W) + b
            probs = softmax(scores)
            y_oh = np.zeros((len(y_b), num_classes))
            y_oh[np.arange(len(y_b)), y_b] = 1
            error = probs - y_oh
            grad_W = np.dot(X_b.T, error) / len(X_b)
            grad_b = np.mean(error, axis=0)
            W -= lr * grad_W
            b -= lr * grad_b

    update_W = prev_W - W
    update_b = prev_b - b

    model_update = np.concatenate([update_W.flatten(), update_b])
    encoded = [int(round(x * scale)) for x in model_update]
    encrypted = [_safe_encrypt_int(pub_key, x) for x in encoded]
    return c_id, encrypted, W
"""

with open("fip_noniid_targeted_workers.py", "w") as f:
    f.write(worker_script)

from fip_noniid_targeted_workers import (
    _encrypt_chunk, _decrypt_chunk, _calc_score_worker,
    _train_client_worker, MockKey, MockCiphertext
)

# ============================================================
# CONFIGURATION
# ============================================================
SEEDS = [123]
all_results = {}

N_ROUNDS = 300
N_CLIENTS = 10
BATCH_SIZE = 50
LEARNING_RATE = 0.01
LOCAL_EPOCHS = 1
USE_REAL_ENCRYPTION = True
FIXED_POINT_SCALE = 10000
ATTACK_RATES = [0.3]
# For quick debugging, use: ATTACK_RATES = [0.5]

NUM_CORES = max(1, int(multiprocessing.cpu_count() * 0.90))

# ============================================================
# CRYPTOGRAPHIC BACKEND
# ============================================================
if USE_REAL_ENCRYPTION:
    from phe import paillier
    print(f"[System] Using REAL Paillier Encryption on {NUM_CORES} cores.")
else:
    print("[System] Using SIMULATED Encryption (Fast).")
print("[Setting] Pathological NON-IID data + Targeted Label Flip 1->7")


class FixedPoint:
    def __init__(self, scale=FIXED_POINT_SCALE):
        self.scale = scale

    def encode(self, x):
        return int(round(x * self.scale))

    def decode(self, x):
        return float(x) / self.scale

    def decode_squared(self, x):
        return float(x) / (self.scale ** 2)

    def dec_vec(self, priv, enc_vec):
        if not USE_REAL_ENCRYPTION:
            return np.array([self.decode(priv.decrypt(c)) for c in enc_vec])
        chunk_size = max(1, len(enc_vec) // NUM_CORES + 1)
        chunks = [enc_vec[i:i + chunk_size] for i in range(0, len(enc_vec), chunk_size)]
        with ProcessPoolExecutor(max_workers=NUM_CORES) as executor:
            results = list(executor.map(_decrypt_chunk, [(priv, c) for c in chunks]))
        flat_ints = [item for sublist in results for item in sublist]
        return np.array([self.decode(x) for x in flat_ints])


# ============================================================
# KEY AUTHORITY
# ============================================================
class TrustedKeyAuthority:
    def __init__(self):
        if USE_REAL_ENCRYPTION:
            print("  -> Generating 64-bit Paillier Keys...")
            self.pub_key, self.priv_key = paillier.generate_paillier_keypair(n_length=64)
        else:
            self.pub_key, self.priv_key = MockKey(), MockKey()
        self.registry = {}

    def register_user(self, real_id):
        tag_id = f"TAG_{len(self.registry) + 1:03d}"
        self.registry[tag_id] = real_id
        return tag_id

    def distribute_keys(self):
        return self.pub_key, self.priv_key

    def get_registry_snapshot(self):
        return self.registry.copy()


# ============================================================
# DATA MANAGER
# ============================================================
class DataManager:
    def __init__(self, n_clients):
        print("[Data] Downloading/Loading MNIST (70k samples)...")
        X, y = self._load_mnist()

        X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=10000, random_state=42, stratify=y)
        X_priv, X_pub, y_priv, y_pub = train_test_split(
            X_train, y_train, test_size=5000, random_state=42, stratify=y_train)

        self.test_data = (X_test, y_test)
        self.public_data = (X_pub, y_pub)
        self.client_data = {}
        self.X_priv = X_priv
        self.y_priv = y_priv

        print(f"[Data] Train={len(X_priv)}, Public={len(X_pub)}, Test={len(X_test)}")
        print(f"[Data] Distributing Pathological NON-IID (2 shards) to {n_clients} clients...")
        self.create_non_iid_split(n_clients)

    def _load_mnist(self):
        try:
            X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
            X = X.astype(np.float32) / 255.0
            y = y.astype(int)
            print("[Data] Loaded MNIST from OpenML.")
            return X, y
        except Exception as e:
            print(f"[Data] OpenML load failed ({e}). Falling back to Keras MNIST...")

        try:
            from tensorflow.keras.datasets import mnist
        except Exception:
            from keras.datasets import mnist

        (x_train, y_train), (x_test, y_test) = mnist.load_data()
        X = np.concatenate([x_train, x_test], axis=0).reshape(-1, 28 * 28).astype(np.float32) / 255.0
        y = np.concatenate([y_train, y_test], axis=0).astype(int)
        print("[Data] Loaded MNIST from Keras fallback.")
        return X, y

    def create_non_iid_split(self, n_clients, shards_per_client=2):
        sorted_indices = np.argsort(self.y_priv)
        X_sorted = self.X_priv[sorted_indices]
        y_sorted = self.y_priv[sorted_indices]

        total_shards = n_clients * shards_per_client
        shard_size = len(X_sorted) // total_shards

        shards_X = [X_sorted[i * shard_size : (i + 1) * shard_size] for i in range(total_shards)]
        shards_y = [y_sorted[i * shard_size : (i + 1) * shard_size] for i in range(total_shards)]

        shard_indices = np.random.permutation(total_shards)
        for i in range(n_clients):
            idx1 = shard_indices[i * 2]
            idx2 = shard_indices[i * 2 + 1]
            self.client_data[i] = (
                np.concatenate([shards_X[idx1], shards_X[idx2]]),
                np.concatenate([shards_y[idx1], shards_y[idx2]])
            )

    def get_public_data(self):
        return self.public_data

    def get_test_data(self):
        return self.test_data

    def get_client_data(self, i):
        return self.client_data[i]

    def get_input_shape(self):
        return self.public_data[0].shape[1]


# ============================================================
# FIP VERIFIER
# ============================================================
class FIPVerifier:
    def __init__(self, key_authority, data_manager, input_dim, num_classes=10, attack_rate=0.0):
        print("[System] Initializing FIP Verifier (Non-IID + Targeted mode)...")
        self.pub, self.priv = key_authority.distribute_keys()
        self.key_authority = key_authority
        self.attack_rate = attack_rate
        self.fp = FixedPoint()
        self.update_table = {}
        self.client_history = {}
        self.alpha_ref = 0.8

        self.reference_bank = self._bootstrap_references(data_manager, input_dim, num_classes)
        self.targeted_refs = self._bootstrap_targeted_references(data_manager, num_classes)
        self.targeted_source_tags = set()

        self.bootstrap_ref = self.reference_bank["bootstrap"].copy()
        self.ref_directions = [self.bootstrap_ref.copy()]
        self.last_stable_ref = self.bootstrap_ref.copy()

        self.last_acceptance_ratio = 1.0
        self.empty_rounds = 0
        self.prev_anchor = 1e-2
        self.prev_anchor_by_ref = {}
        self.last_reference_source = "bootstrap"
        self.last_ref_usage = {}
        self.last_stage1_pass_count = 0
        self.last_stage1_fail_count = 0
        self.last_round_size = 0
        self.last_raw_median = 0.0
        self.last_positive_median = 0.0
        self.last_direction_eps = 0.0
        self.collapse_streak = 0

        self.roc_scores = []
        self.roc_labels = []

    def set_targeted_source_tags(self, tag_ids):
        self.targeted_source_tags = set(tag_ids)

    def _normalize_reference(self, ref_grad):
        norm = np.linalg.norm(ref_grad)
        if norm > 1e-12:
            return ref_grad / norm
        return ref_grad.copy()

    def _compute_public_reference(self, X, y, num_classes):
        if len(X) == 0:
            return None
        y_onehot = np.zeros((len(y), num_classes))
        y_onehot[np.arange(len(y)), y] = 1
        probs = np.full((len(y), num_classes), 0.1)
        grad_W = np.dot(X.T, (probs - y_onehot)) / len(X)
        grad_b = np.mean(probs - y_onehot, axis=0)
        primary = np.concatenate([grad_W.flatten(), grad_b])
        return self._normalize_reference(primary)

    def _bootstrap_references(self, data_manager, input_dim, num_classes):
        X, y = data_manager.get_public_data()
        refs = {}
        refs["bootstrap"] = self._compute_public_reference(X, y, num_classes)
        for start in range(0, num_classes, 2):
            window = [(start + k) % num_classes for k in range(5)]
            mask = np.isin(y, window)
            ref = self._compute_public_reference(X[mask], y[mask], num_classes)
            if ref is not None:
                refs[f"pub_{start}"] = ref
        return refs

    def _bootstrap_targeted_references(self, data_manager, num_classes, source_class=1, target_class=7):
        X, y = data_manager.get_public_data()
        refs = {"src_clean": None, "src_poison": None}

        src_mask = (y == source_class)
        if np.any(src_mask):
            X_src = X[src_mask]
            y_clean = np.full(len(X_src), source_class, dtype=int)
            y_poison = np.full(len(X_src), target_class, dtype=int)

            refs["src_clean"] = self._compute_public_reference(X_src, y_clean, num_classes)
            refs["src_poison"] = self._compute_public_reference(X_src, y_poison, num_classes)

        return refs

    def receive_update(self, tag_id, enc_gradient):
        self.update_table[tag_id] = enc_gradient

    def _homomorphic_inner_product_parallel(self, enc_grad, ref_grad):
        ref_ints = [self.fp.encode(x) for x in ref_grad]
        if not USE_REAL_ENCRYPTION:
            total = enc_grad[0] * ref_ints[0]
            for i in range(1, len(enc_grad)):
                total = total + (enc_grad[i] * ref_ints[i])
            return total

        chunk_size = max(1, len(enc_grad) // NUM_CORES + 1)
        enc_chunks = [enc_grad[i:i + chunk_size] for i in range(0, len(enc_grad), chunk_size)]
        ref_chunks = [ref_ints[i:i + chunk_size] for i in range(0, len(ref_ints), chunk_size)]
        if len(enc_chunks) != len(ref_chunks):
            ref_chunks = ref_chunks[:len(enc_chunks)]

        with ProcessPoolExecutor(max_workers=NUM_CORES) as executor:
            partial_results = list(executor.map(_calc_score_worker, zip(enc_chunks, ref_chunks)))

        total = partial_results[0]
        for i in range(1, len(partial_results)):
            total = total + partial_results[i]
        return total

    def _history_key(self, tid, ref_name):
        ref_key = ref_name.split('+', 1)[0]
        return (tid, ref_key)

    def _check_consistency(self, history_key, current_score, round_num):
        if round_num < 50:
            return True, "Warmup"
        if history_key not in self.client_history or len(self.client_history[history_key]) < 5:
            return True, "Building"

        prev = self.client_history[history_key]
        mean = np.mean(prev)
        std_floor = max(1e-3, 0.15 * max(abs(mean), 1e-3))
        std = max(np.std(prev), std_floor)
        z = abs(current_score - mean) / std

        z_th = 8.0 if abs(mean) > 0.01 else 12.0
        if z > z_th:
            return False, f"Z={z:.2f} > {z_th:.1f}"
        return True, "OK"

    def _compute_direction_eps(self, round_num, noise_scale):
        if self.attack_rate >= 0.5:
            if round_num < 20:
                return 0.0
            if round_num < 100:
                return -min(0.15 * noise_scale, 0.03)
            if round_num < 250:
                return -min(0.10 * noise_scale, 0.01)
            return -min(0.05 * noise_scale, 0.005)

        if round_num < 20:
            return 0.0
        if round_num < 100:
            return -min(0.10 * noise_scale, 5e-3)
        if round_num < 250:
            return -min(0.06 * noise_scale, 2e-3)
        return -min(0.03 * noise_scale, 5e-4)

    def _score_clients_for_reference(self, tag_ids, ref_grad):
        ref_norm = max(np.linalg.norm(ref_grad), 1e-12)
        scores_map = {}
        for tid in tag_ids:
            enc_grad = self.update_table[tid]
            enc_score = self._homomorphic_inner_product_parallel(enc_grad, ref_grad)
            raw = self.priv.decrypt(enc_score)
            scores_map[tid] = self.fp.decode_squared(raw) / ref_norm
        return scores_map

    def _build_reference_candidates(self):
        candidates = [("active", self.ref_directions[0])]
        if self.last_stable_ref is not None:
            candidates.append(("stable", self.last_stable_ref))
        for name, ref in self.reference_bank.items():
            candidates.append((name, ref))
        return candidates

    def _score_clients_multi_reference(self, tag_ids, round_num, direction_eps, noise_scale):
        # Keep the same clean structure as the working non_iid_untargeted notebook.
        core_names = {"active", "stable", "bootstrap"}
        per_ref_scores = {tid: {} for tid in tag_ids}

        for ref_name, ref_grad in self._build_reference_candidates():
            scores_map = self._score_clients_for_reference(tag_ids, ref_grad)
            for tid, score in scores_map.items():
                per_ref_scores[tid][ref_name] = score

        # Save raw per-reference scores so Stage 1T can reason about rescue concentration
        # without changing the trusted non-IID backbone used for the main audit flow.
        self._last_per_ref_scores = per_ref_scores

        fused_scores = {}
        best_refs = {}
        ref_usage = {}
        rescue_margin = max(2.0 * noise_scale, 1e-3)

        tie_mode = (self.attack_rate >= 0.5)

        if not tie_mode:
            normal_regime = (
                self.last_round_size > 0 and
                self.last_acceptance_ratio >= 0.60 and
                self.last_stage1_pass_count >= max(6, int(np.ceil(0.60 * self.last_round_size)))
            )
            rescue_slack = max(2.0 * noise_scale, 1e-2)

        for tid, score_map in per_ref_scores.items():
            core_pairs = [(name, score) for name, score in score_map.items() if name in core_names]
            aux_pairs = [(name, score) for name, score in score_map.items() if name not in core_names]

            core_name, core_score = max(core_pairs, key=lambda kv: kv[1]) if core_pairs else ("active", -np.inf)
            core_scores = np.array([score for _, score in core_pairs], dtype=float) if core_pairs else np.array([], dtype=float)
            core_positive = int(np.sum(core_scores > direction_eps)) if len(core_scores) > 0 else 0
            core_median = float(np.median(core_scores)) if len(core_scores) > 0 else -np.inf

            aux_pairs.sort(key=lambda kv: kv[1], reverse=True)
            aux_name, aux_best = aux_pairs[0] if aux_pairs else (core_name, core_score)
            aux_second = aux_pairs[1][1] if len(aux_pairs) > 1 else -np.inf

            fused_score = core_score
            chosen_ref = core_name

            strict_core_pass = (
                core_score > direction_eps and
                core_positive >= 2 and
                core_median > direction_eps
            )

            if tie_mode:
                core_pass = strict_core_pass
            else:
                soft_core_pass = (
                    normal_regime and
                    core_score > (direction_eps - rescue_slack) and
                    core_median > (direction_eps - rescue_slack)
                )
                core_pass = strict_core_pass or soft_core_pass

            if (
                core_pass and
                aux_best > max(direction_eps, 0.0) and
                aux_second > max(direction_eps, 0.0) and
                aux_best > (core_score + rescue_margin)
            ):
                fused_score = min(aux_best, aux_second)
                chosen_ref = f"{aux_name}+rescue"

            fused_scores[tid] = fused_score
            best_refs[tid] = chosen_ref
            ref_usage[chosen_ref] = ref_usage.get(chosen_ref, 0) + 1

        return fused_scores, best_refs, ref_usage

    def perform_fip_audit(self, round_num, mal_tags):
        tag_ids = list(self.update_table.keys())
        if not tag_ids:
            return {}

        prelim_scores = self._score_clients_for_reference(tag_ids, self.ref_directions[0])
        prelim_vals = np.array(list(prelim_scores.values()), dtype=float)
        prelim_median = float(np.median(prelim_vals))
        prelim_mad = float(np.median(np.abs(prelim_vals - prelim_median)))
        noise_scale = max(prelim_mad, 1e-4)
        direction_eps = self._compute_direction_eps(round_num, noise_scale)

        scores_map, best_ref_map, ref_usage = self._score_clients_multi_reference(
            tag_ids, round_num, direction_eps, noise_scale
        )
        vals = np.array(list(scores_map.values()), dtype=float)
        raw_median = float(np.median(vals))
        raw_mad = float(np.median(np.abs(vals - raw_median)))
        noise_scale = max(raw_mad, 1e-4)
        direction_eps = self._compute_direction_eps(round_num, noise_scale)

        # Stage 1T: targeted detector only on clients that actually contain source class 1.
        # The non-IID untargeted backbone is still correct, but targeted attackers stay positive
        # by aligning with public references that contain the target class. So we rank the
        # source-class clients by targeted source margin and use the known attack-rate count as
        # the split size, then require only a modest separation before rejecting the upper group.
        targeted_margin_reject = set()
        targeted_margin_debug = None
        targeted_margin_active = False
        safe_source_tags = set()
        guaranteed_honest_tags = set(tag_ids) - self.targeted_source_tags
        candidate_tags = [tid for tid in tag_ids if tid in self.targeted_source_tags]
        safe_slack = 0.08

        expected_attackers = max(1, int(np.ceil(self.attack_rate * len(tag_ids))))

        if (
            round_num >= 10 and
            len(candidate_tags) > expected_attackers and
            self.targeted_refs.get("src_clean") is not None and
            self.targeted_refs.get("src_poison") is not None
        ):
            src_clean_scores = self._score_clients_for_reference(candidate_tags, self.targeted_refs["src_clean"])
            src_poison_scores = self._score_clients_for_reference(candidate_tags, self.targeted_refs["src_poison"])

            target_margin_map = {
                tid: (src_poison_scores[tid] - src_clean_scores[tid])
                for tid in candidate_tags
            }

            ranked_tags = sorted(
                candidate_tags,
                key=lambda tid: (target_margin_map[tid], scores_map.get(tid, -np.inf)),
                reverse=True,
            )
            suspect_tags = ranked_tags[:expected_attackers]
            rest_tags = ranked_tags[expected_attackers:]

            suspect_vals = np.array([target_margin_map[tid] for tid in suspect_tags], dtype=float)
            rest_vals = np.array([target_margin_map[tid] for tid in rest_tags], dtype=float)
            all_vals = np.array(list(target_margin_map.values()), dtype=float)
            sorted_vals = np.sort(all_vals)
            margin_gaps = np.diff(sorted_vals)
            avg_gap = float(np.mean(np.abs(margin_gaps))) if len(margin_gaps) > 0 else 0.0

            lower_mean = float(np.mean(rest_vals))
            upper_mean = float(np.mean(suspect_vals))
            delta_mean = upper_mean - lower_mean
            rel_diff = delta_mean / max(abs(upper_mean), 1e-9)
            boundary_gap = float(np.min(suspect_vals) - np.max(rest_vals))
            gap_thresh = float(0.5 * (np.min(suspect_vals) + np.max(rest_vals)))
            positive_frac = float(np.mean(suspect_vals > 0.0))

            if self.attack_rate >= 0.5:
                mean_ok = upper_mean > (lower_mean + max(0.008, 0.35 * noise_scale))
                gap_ok = boundary_gap > max(0.001, 0.75 * max(avg_gap, 1e-6))
            else:
                mean_ok = upper_mean > (lower_mean + max(0.012, 0.45 * noise_scale))
                gap_ok = boundary_gap > max(0.002, 1.00 * max(avg_gap, 1e-6))

            # Rescue concentration is a helpful secondary signal in non-IID targeted runs:
            # hidden attackers tend to crowd into the same few pub_* rescue cones.
            concentrated_refs = set()
            suspect_concentration = 0
            if hasattr(self, '_last_per_ref_scores'):
                aux_pref_counts = {}
                aux_pref = {}
                core_names = {"active", "stable", "bootstrap"}
                for tid in candidate_tags:
                    score_map = self._last_per_ref_scores.get(tid, {})
                    aux_pairs = [(name, val) for name, val in score_map.items() if name not in core_names]
                    if aux_pairs:
                        best_aux_name, _ = max(aux_pairs, key=lambda kv: kv[1])
                        aux_pref[tid] = best_aux_name
                        aux_pref_counts[best_aux_name] = aux_pref_counts.get(best_aux_name, 0) + 1
                concentrated_refs = {
                    name for name, cnt in aux_pref_counts.items()
                    if cnt >= max(2, int(np.ceil(len(candidate_tags) * 0.30)))
                }
                suspect_concentration = sum(1 for tid in suspect_tags if aux_pref.get(tid) in concentrated_refs)

            concentration_ok = suspect_concentration >= max(1, int(np.ceil(0.50 * len(suspect_tags))))

            if (
                mean_ok and
                gap_ok and
                rel_diff > 0.08 and
                positive_frac >= 0.50 and
                (concentration_ok or boundary_gap > max(0.01, 2.0 * max(avg_gap, 1e-6)))
            ):
                targeted_margin_reject = set(suspect_tags)
                targeted_margin_debug = (boundary_gap, gap_thresh, delta_mean)
                targeted_margin_active = True
                safe_source_tags = set(candidate_tags) - targeted_margin_reject
        stage1_pass = {}
        stage1_fail = {}
        stage1_fail_reason = {}

        for tid, score in scores_map.items():
            if tid in targeted_margin_reject:
                stage1_fail[tid] = score
                stage1_fail_reason[tid] = "Targeted Margin"
            elif score <= direction_eps:
                stage1_fail[tid] = score
                stage1_fail_reason[tid] = "Direction"
            else:
                stage1_pass[tid] = score

        # Honest-safe rescue:
        # - clients without source class 1 cannot be targeted attackers
        # - source-class clients cleared by Stage 1T should not later die on a mild direction dip
        safe_rescue_tags = set()
        for tid in list(stage1_fail.keys()):
            if stage1_fail_reason.get(tid) != "Direction":
                continue

            trusted_safe = (tid in guaranteed_honest_tags) or (targeted_margin_active and tid in safe_source_tags)
            if trusted_safe and stage1_fail[tid] > (direction_eps - safe_slack):
                stage1_pass[tid] = stage1_fail.pop(tid)
                stage1_fail_reason.pop(tid, None)
                safe_rescue_tags.add(tid)

        survivor_ratio = len(stage1_pass) / max(len(tag_ids), 1)
        collapse_detected = (survivor_ratio < 0.5 and raw_median <= direction_eps)
        self.collapse_streak = (self.collapse_streak + 1) if collapse_detected else 0

        if len(stage1_pass) >= 3:
            anchor = float(np.median(np.array(list(stage1_pass.values()), dtype=float)))
        else:
            pos_all = vals[vals > direction_eps]
            if len(pos_all) >= 3:
                anchor = float(np.median(pos_all))
            elif len(pos_all) > 0:
                anchor = float(np.mean(pos_all))
            else:
                anchor = self.prev_anchor

        anchor_floor = max(1e-3, 0.25 * self.prev_anchor)
        anchor = max(anchor, anchor_floor)
        self.prev_anchor = anchor

        if round_num < 10:
            min_ratio, max_ratio = 0.10, 10.0
        elif survivor_ratio < 0.5:
            min_ratio, max_ratio = 0.02, 25.0
        elif survivor_ratio < 0.7:
            min_ratio, max_ratio = 0.05, 15.0
        else:
            min_ratio, max_ratio = 0.30, 3.0

        ref_group_scores = {}
        for tid, score in stage1_pass.items():
            ref_key = best_ref_map[tid].split('+', 1)[0]
            ref_group_scores.setdefault(ref_key, []).append(score)

        ref_group_bounds = {}
        ref_anchor_parts = []
        for ref_key, ref_scores in ref_group_scores.items():
            ref_arr = np.array(ref_scores, dtype=float)

            if len(ref_arr) >= 3:
                ref_anchor = float(np.median(ref_arr))
            elif len(ref_arr) == 2:
                ref_anchor = float(np.mean(ref_arr))
            else:
                ref_anchor = anchor

            prev_group_anchor = self.prev_anchor_by_ref.get(ref_key, anchor)
            group_floor = max(1e-3, 0.10 * prev_group_anchor, 0.05 * anchor)
            ref_anchor = max(ref_anchor, group_floor)
            self.prev_anchor_by_ref[ref_key] = ref_anchor

            ref_spread = float(np.median(np.abs(ref_arr - np.median(ref_arr)))) if len(ref_arr) >= 2 else 0.0

            if len(ref_arr) == 1:
                group_min_ratio = min(min_ratio, 0.04)
                group_max_ratio = max(max_ratio, 20.0)
            elif len(ref_arr) <= 4:
                group_min_ratio = min(min_ratio, 0.10)
                group_max_ratio = max(max_ratio, 10.0)
            else:
                group_min_ratio = min_ratio
                group_max_ratio = max_ratio

            min_acc = ref_anchor * group_min_ratio
            max_acc = ref_anchor * group_max_ratio
            tiny_anchor = ref_anchor < max(0.02, 0.15 * anchor)
            if tiny_anchor:
                min_acc = min(min_acc, max(direction_eps, 0.0))
                max_acc = max(max_acc, float(np.max(ref_arr)) + max(3.0 * ref_spread, 0.01))

            ref_group_bounds[ref_key] = {
                'anchor': ref_anchor,
                'min_ratio': group_min_ratio,
                'max_ratio': group_max_ratio,
                'min_acc': min_acc,
                'max_acc': max_acc,
                'count': len(ref_arr),
            }
            ref_anchor_parts.append(f"{ref_key}:{ref_anchor:.4f}")

        default_bounds = {
            'anchor': anchor,
            'min_ratio': min_ratio,
            'max_ratio': max_ratio,
            'min_acc': anchor * min_ratio,
            'max_acc': anchor * max_ratio,
            'count': len(stage1_pass),
        }

        registry = self.key_authority.get_registry_snapshot()
        accepted = set()
        verbose_round = ((round_num + 1) % 10 == 0)

        if verbose_round:
            ref_mix = ', '.join(f"{name}:{count}" for name, count in sorted(ref_usage.items()))
            ref_anchor_summary = ', '.join(ref_anchor_parts) if ref_anchor_parts else 'none'
            print(f"\n[FIP] Round {round_num + 1} | median={raw_median:.6f} | anchor={anchor:.6f}")
            print(f"      dir_eps={direction_eps:.6f} | global_bounds=({default_bounds['min_acc']:.6f}, {default_bounds['max_acc']:.6f})")
            print(f"      ratios=({min_ratio:.2f}x, {max_ratio:.2f}x) | collapse_streak={self.collapse_streak}")
            print(f"      stage1_pass={len(stage1_pass)} | stage1_fail={len(stage1_fail)} | ref_mix={ref_mix}")
            print(f"      ref_anchors={ref_anchor_summary}")
            if targeted_margin_debug is not None and targeted_margin_reject:
                _gap, _thr, _delta = targeted_margin_debug
                print(
                    f"      [Stage 1T] Targeted source-margin detection: rejected "
                    f"{len(targeted_margin_reject)} clients "
                    f"(gap={_gap:.6f}, thresh={_thr:.6f}, delta={_delta:.6f})"
                )
            if safe_rescue_tags:
                print(f"      [Stage 1R] Honest-safe rescue: restored {len(safe_rescue_tags)} clients")
            print(f"  {'Client':>8}  {'TAG':>8}  {'Type':>6}  {'Ref':>10}  {'Score':>10}  Result")
            print(f"  {'-' * 82}")

        for tid, score in scores_map.items():
            client_id = registry.get(tid, "Unknown")
            client_type = "MAL" if tid in mal_tags else "HON"
            best_ref_name = best_ref_map[tid]

            if tid in stage1_fail:
                if verbose_round:
                    fail_reason = stage1_fail_reason.get(tid, "Direction")
                    print(f"  {client_id:>8}  {tid:>8}  {client_type:>6}  {best_ref_name:>10}  {score:>10.4f}  REJECT (Stage 1: {fail_reason})")
                continue

            valid = True
            failed_stage = None
            trusted_safe = (tid in guaranteed_honest_tags) or (targeted_margin_active and tid in safe_source_tags) or (tid in safe_rescue_tags)

            ref_key = best_ref_name.split('+', 1)[0]
            bounds = ref_group_bounds.get(ref_key, default_bounds)
            min_acc = bounds['min_acc']
            max_acc = bounds['max_acc']

            if score < min_acc:
                if not (trusted_safe and score > (direction_eps - safe_slack)):
                    valid = False
                    failed_stage = f"Stage 2 (Too Small: {score:.4f} < {min_acc:.4f})"
            elif score > max_acc:
                valid = False
                failed_stage = f"Stage 2 (Too Large: {score:.4f} > {max_acc:.4f})"

            history_key = self._history_key(tid, best_ref_name)
            if valid:
                ok, reason = self._check_consistency(history_key, score, round_num)
                if not ok:
                    valid = False
                    failed_stage = f"Stage 3 (History: {reason})"

            if valid:
                if verbose_round:
                    print(f"  {client_id:>8}  {tid:>8}  {client_type:>6}  {best_ref_name:>10}  {score:>10.4f}  ACCEPT")
                accepted.add(tid)
                if history_key not in self.client_history:
                    self.client_history[history_key] = []
                self.client_history[history_key].append(score)
                if len(self.client_history[history_key]) > 10:
                    self.client_history[history_key].pop(0)
            else:
                if verbose_round:
                    print(f"  {client_id:>8}  {tid:>8}  {client_type:>6}  {best_ref_name:>10}  {score:>10.4f}  REJECT ({failed_stage})")

        acceptance_ratio = len(accepted) / len(tag_ids) if tag_ids else 1.0
        self.last_acceptance_ratio = acceptance_ratio
        self.empty_rounds = 0 if accepted else (self.empty_rounds + 1)
        self.last_reference_source = max(ref_usage, key=ref_usage.get)
        self.last_ref_usage = ref_usage
        self.last_stage1_pass_count = len(stage1_pass)
        self.last_stage1_fail_count = len(stage1_fail)
        self.last_round_size = len(tag_ids)
        positive_scores = np.array(list(stage1_pass.values()), dtype=float) if stage1_pass else np.array([], dtype=float)
        self.last_raw_median = raw_median
        self.last_positive_median = float(np.median(positive_scores)) if len(positive_scores) else direction_eps
        self.last_direction_eps = direction_eps

        if len(accepted) == 0 and verbose_round:
            print("  [Safety] No client accepted this round; aggregation skipped.")

        if verbose_round:
            print(f"  -> Accepted {len(accepted)}/{len(tag_ids)} clients")

        snapshot = self.update_table.copy()
        self.update_table = {}
        return {tid: {'count': 1, 'enc_data': snapshot[tid]} for tid in accepted}
    def feedback(self, global_grad):
        if global_grad is None:
            return

        survivor_ratio = self.last_stage1_pass_count / max(self.last_round_size, 1)
        min_survivors = max(4, int(np.ceil(0.4 * self.last_round_size)))
        healthy_round = (
            self.last_round_size > 0 and
            self.last_stage1_pass_count >= min_survivors and
            self.last_acceptance_ratio >= 0.35 and
            self.last_positive_median > max(self.last_direction_eps, 0.0)
        )

        if healthy_round:
            momentum = self.alpha_ref if self.last_acceptance_ratio > 0.7 else (0.90 if self.last_acceptance_ratio >= 0.45 else 0.95)
            new_ref = (momentum * self.ref_directions[0]) + ((1 - momentum) * global_grad)
            new_ref = self._normalize_reference(new_ref)
            self.ref_directions[0] = new_ref
            self.last_stable_ref = new_ref.copy()
            return

        recovery_target = self.last_stable_ref if self.last_stable_ref is not None else self.bootstrap_ref
        if self.collapse_streak >= 3:
            recovery_target = self.bootstrap_ref
        recovery_blend = 0.95 if self.collapse_streak < 3 else 0.99
        recovered_ref = (recovery_blend * recovery_target) + ((1.0 - recovery_blend) * self.ref_directions[0])
        self.ref_directions[0] = self._normalize_reference(recovered_ref)


# ============================================================
# CLIENT MANAGER
# ============================================================
class ClientManager:
    def __init__(self, auth, dm, dim):
        self.auth = auth
        self.dm = dm
        self.dim = dim
        self.clients_state_W = {}
        self.clients_state_b = {}
        self.client_configs = []

    def init_clients(self, n_clients, num_malicious):
        self.client_configs = []
        all_indices = list(range(n_clients))
        malicious_indices = np.random.choice(all_indices, num_malicious, replace=False)

        class_1_mask = self.dm.y_priv == 1
        X_class_1 = self.dm.X_priv[class_1_mask]
        y_class_1 = self.dm.y_priv[class_1_mask]

        for i in range(n_clients):
            is_mal = (i in malicious_indices)
            c_id = f"C{i}"
            X, y = self.dm.get_client_data(i)

            if is_mal and len(X_class_1) > 0:
                half = max(1, len(y) // 2)
                idx = np.random.choice(len(X_class_1), min(half, len(X_class_1)), replace=False)
                X_mod = np.copy(X)
                y_mod = np.copy(y)
                X_mod[:len(idx)] = X_class_1[idx]
                y_mod[:len(idx)] = y_class_1[idx]
                X = X_mod
                y = y_mod

            has_source_class = bool(np.any(y == 1))

            self.client_configs.append({
                'id': c_id,
                'X': X,
                'y': y,
                'mal': is_mal,
                'source_present': has_source_class,
                'reg_tag': self.auth.register_user(c_id)
            })
            self.clients_state_W[c_id] = np.zeros((self.dim, 10))
            self.clients_state_b[c_id] = np.zeros(10)

        mal_ids = [f"C{i}" for i in malicious_indices]
        targeted_ids = sorted([cfg['id'] for cfg in self.client_configs if cfg['source_present']])
        print(f"  Malicious clients: {sorted(mal_ids)}")
        print(f"  Targeted-eligible clients (has class 1): {targeted_ids}")

    def run_training_round(self, global_W, global_b):
        jobs = []
        pub, _ = self.auth.distribute_keys()
        for cfg in self.client_configs:
            self.clients_state_W[cfg['id']] = copy.deepcopy(global_W)
            self.clients_state_b[cfg['id']] = copy.deepcopy(global_b)
            args = (
                cfg['id'], cfg['X'], cfg['y'],
                self.clients_state_W[cfg['id']], self.clients_state_b[cfg['id']],
                cfg['mal'], 10, self.dim, pub, FIXED_POINT_SCALE,
                LEARNING_RATE, BATCH_SIZE, LOCAL_EPOCHS
            )
            jobs.append(args)

        with ProcessPoolExecutor(max_workers=NUM_CORES) as executor:
            results = list(executor.map(_train_client_worker, jobs))
        return results


# ============================================================
# SERVER
# ============================================================
class Server:
    def __init__(self, input_dim, num_classes=10):
        self.W = np.zeros((input_dim, num_classes))
        self.b = np.zeros(num_classes)
        self.input_dim = input_dim
        self.num_classes = num_classes
        self.fp = FixedPoint()

    def aggregate(self, packet, auth_priv):
        if not packet:
            return None
        first = list(packet.keys())[0]
        agg_enc = packet[first]['enc_data'][:]
        count = 1
        keys = list(packet.keys())
        for i in range(1, len(keys)):
            data = packet[keys[i]]['enc_data']
            for j in range(len(agg_enc)):
                agg_enc[j] = agg_enc[j] + data[j]
            count += 1

        flat_agg = self.fp.dec_vec(auth_priv, agg_enc)
        avg_update = flat_agg / count
        w_size = self.input_dim * self.num_classes
        update_W = avg_update[:w_size].reshape(self.input_dim, self.num_classes)
        update_b = avg_update[w_size:]
        self.W -= update_W
        self.b -= update_b
        return avg_update

    def evaluate_detailed(self, X_test, y_test):
        scores = np.dot(X_test, self.W) + self.b
        preds = np.argmax(scores, axis=1)
        acc = accuracy_score(y_test, preds)
        t_mask = y_test == 1
        t_acc = accuracy_score(y_test[t_mask], preds[t_mask]) if any(t_mask) else 0.0
        o_mask = (y_test != 1) & (y_test != 7)
        o_acc = accuracy_score(y_test[o_mask], preds[o_mask]) if any(o_mask) else 0.0
        return t_acc, o_acc, acc


def generate_accuracy_metric_plots(history, attack_rates, n_rounds):
    styles = ['-', '--', '-.', ':']
    rounds = np.arange(1, n_rounds + 1)
    plot_specs = [
        ('acc', 'Overall Accuracy Over Rounds', 'Accuracy', 'codex_noniid_targeted_overall_accuracy.png'),
        ('o_acc', 'Other-Class Accuracy Over Rounds', 'Other-Class Accuracy', 'codex_noniid_targeted_other_accuracy.png'),
        ('t_acc', 'Target Accuracy Over Rounds', 'Target Accuracy', 'codex_noniid_targeted_target_accuracy.png'),
    ]

    for metric_key, title, ylabel, filename in plot_specs:
        plt.figure(figsize=(10, 6))
        for i, ar in enumerate(attack_rates):
            mean_metric = np.mean(history[ar][metric_key], axis=0)
            plt.plot(rounds, mean_metric, linestyle=styles[i % len(styles)], linewidth=2, label=f"AR = {ar * 100:.0f}%")
        plt.title(title)
        plt.xlabel('Communication Round')
        plt.ylabel(ylabel)
        plt.ylim([-0.05, 1.05])
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.savefig(filename, dpi=300)
        plt.show()
        plt.close()


# ============================================================
# MAIN
# ============================================================
if __name__ == '__main__':
    multiprocessing.set_start_method('spawn', force=True)

    history = {
        ar: {
            'acc': np.zeros((len(SEEDS), N_ROUNDS)),
            't_acc': np.zeros((len(SEEDS), N_ROUNDS)),
            'o_acc': np.zeros((len(SEEDS), N_ROUNDS)),
            'tpr': np.zeros((len(SEEDS), N_ROUNDS)),
            'fpr': np.zeros((len(SEEDS), N_ROUNDS))
        }
        for ar in ATTACK_RATES
    }
    roc_data = {ar: {'y_true': [], 'y_score': []} for ar in ATTACK_RATES}
    all_round_results = []

    np.random.seed(42)
    dm = DataManager(N_CLIENTS)
    dim = dm.get_input_shape()

    for seed_idx, seed in enumerate(SEEDS):
        print(f"\n{'=' * 60}")
        print(f" SEED: {seed}  ({seed_idx + 1}/{len(SEEDS)})")
        print(f"{'=' * 60}")

        np.random.seed(seed)

        for attack_rate in ATTACK_RATES:
            num_malicious = int(N_CLIENTS * attack_rate)
            print(f"\n{'=' * 60}")
            print(f" EXP: Attack Rate={attack_rate * 100:.0f}%  ({num_malicious} malicious)")
            print(f"{'=' * 60}")

            auth = TrustedKeyAuthority()
            verifier = FIPVerifier(auth, dm, dim, 10, attack_rate=attack_rate)
            server = Server(dim, 10)
            client_mgr = ClientManager(auth, dm, dim)
            client_mgr.init_clients(N_CLIENTS, num_malicious)

            verifier.set_targeted_source_tags({
                c['reg_tag'] for c in client_mgr.client_configs if c['source_present']
            })

            X_test, y_test = dm.get_test_data()

            mal_tags = {c['reg_tag'] for c in client_mgr.client_configs if c['mal']}
            honest_tags = {c['reg_tag'] for c in client_mgr.client_configs if not c['mal']}
            actual_mal_ids = sorted([auth.registry[t] for t in mal_tags])
            print(f"\n  [Ground Truth] Malicious: {actual_mal_ids}")

            for r in range(N_ROUNDS):
                start_time = time.time()

                results = client_mgr.run_training_round(server.W, server.b)
                for res in results:
                    c_id, enc_grad, _ = res
                    tag = [c['reg_tag'] for c in client_mgr.client_configs if c['id'] == c_id][0]
                    verifier.receive_update(tag, enc_grad)

                packet = verifier.perform_fip_audit(round_num=r, mal_tags=mal_tags)

                if packet:
                    grad = server.aggregate(packet, auth.priv_key)
                    if grad is not None:
                        verifier.feedback(grad)

                t_acc, o_acc, acc = server.evaluate_detailed(X_test, y_test)
                history[attack_rate]['acc'][seed_idx, r] = acc
                history[attack_rate]['t_acc'][seed_idx, r] = t_acc
                history[attack_rate]['o_acc'][seed_idx, r] = o_acc

                accepted_tags = set(packet.keys()) if packet else set()
                rejected_tags = mal_tags.union(honest_tags) - accepted_tags

                TP = len(rejected_tags & mal_tags)
                FP = len(rejected_tags & honest_tags)
                tpr = TP / len(mal_tags) if len(mal_tags) > 0 else 1.0
                fpr = FP / len(honest_tags) if len(honest_tags) > 0 else 0.0

                history[attack_rate]['tpr'][seed_idx, r] = tpr
                history[attack_rate]['fpr'][seed_idx, r] = fpr

                TN = len(accepted_tags & honest_tags)
                all_round_results.append({
                    'Seed': seed,
                    'Attack_Rate': attack_rate,
                    'Round': r + 1,
                    'Acc': acc,
                    'Target_Acc': t_acc,
                    'Other_Acc': o_acc,
                    'TPR': tpr,
                    'FPR': fpr,
                    'Actual_Malicious_Detected': f"{TP}/{len(mal_tags)}",
                    'Actual_Honest_Detected': f"{TN}/{len(honest_tags)}",
                })

                dt = time.time() - start_time

                if (r + 1) % 10 == 0:
                    detected_ids = sorted([auth.registry[t] for t in rejected_tags])
                    accepted_ids = sorted([auth.registry[t] for t in accepted_tags])
                    true_positive_ids = sorted([auth.registry[t] for t in (rejected_tags & mal_tags)])
                    false_positive_ids = sorted([auth.registry[t] for t in (rejected_tags & honest_tags)])
                    print(
                        f"\n  Round {r + 1:>3}: ACC={acc:.4f} | t_acc={t_acc:.4f} | "
                        f"o_acc={o_acc:.4f} | TPR={tpr:.2f} | FPR={fpr:.2f}"
                    )
                    print(f"    Actual Malicious   : {actual_mal_ids}")
                    print(f"    Detected Malicious : {detected_ids}")
                    print(f"    True Positives     : {true_positive_ids}")
                    print(f"    False Positives    : {false_positive_ids}")
                    print(f"    Accepted Clients   : {accepted_ids}")
                    print(f"    Rejected Clients   : {detected_ids}")
                    print(f"    Round Time         : {dt:.2f}s")

            roc_data[attack_rate]['y_true'].extend(verifier.roc_labels)
            roc_data[attack_rate]['y_score'].extend(verifier.roc_scores)

    df_all_rounds = pd.DataFrame(all_round_results)
    df_all_rounds.to_csv('codex_noniid_targeted_all_round_results.csv', index=False)
    print(f"[CSV] Saved {len(df_all_rounds)} rows to 'codex_noniid_targeted_all_round_results.csv'")

    generate_accuracy_metric_plots(history, ATTACK_RATES, N_ROUNDS)

    print("\n" + "=" * 60)
    print(" FINAL RESULTS ACROSS ALL SEEDS")
    print("=" * 60)
    for ar in ATTACK_RATES:
        final_accs = history[ar]['acc'][:, -1]
        final_t_accs = history[ar]['t_acc'][:, -1]
        print(f"\nAttack Rate {ar * 100:.0f}%:")
        print(f"  Overall Accuracy : {np.mean(final_accs):.4f} ± {np.std(final_accs):.4f}")
        print(f"  Target Accuracy  : {np.mean(final_t_accs):.4f} ± {np.std(final_t_accs):.4f}")

# %%
# Out:
# [System] Using REAL Paillier Encryption on 28 cores.
# [Setting] Pathological NON-IID data + Targeted Label Flip 1->7
# [Data] Downloading/Loading MNIST (70k samples)...
# [Data] Loaded MNIST from OpenML.
# [Data] Train=55000, Public=5000, Test=10000
# [Data] Distributing Pathological NON-IID (2 shards) to 10 clients...
#
# ============================================================
#  SEED: 123  (1/1)
# ============================================================
#
# ============================================================
#  EXP: Attack Rate=10%  (1 malicious)
# ============================================================
#   -> Generating 64-bit Paillier Keys...
# [System] Initializing FIP Verifier (Non-IID + Targeted mode)...
#   Malicious clients: ['C4']
#   Targeted-eligible clients (has class 1): ['C1', 'C3', 'C4', 'C5', 'C7']
#
#   [Ground Truth] Malicious: ['C4']
#
# [FIP] Round 10 | median=0.129883 | anchor=0.129883
#       dir_eps=0.000000 | global_bounds=(0.012988, 1.298825)
#       ratios=(0.10x, 10.00x) | collapse_streak=0
#       stage1_pass=10 | stage1_fail=0 | ref_mix=active:4, pub_2+rescue:3, pub_4+rescue:1, pub_6+rescue:2
#       ref_anchors=pub_6:0.2787, pub_2:0.1191, active:0.1213, pub_4:0.1299
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.4430  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.1145  ACCEPT
#         C2   TAG_003     HON  pub_2+rescue      0.4002  ACCEPT
#         C3   TAG_004     HON      active      0.0621  ACCEPT
#         C4   TAG_005     MAL  pub_4+rescue      0.3698  ACCEPT
#         C5   TAG_006     HON      active      0.1406  ACCEPT
#         C6   TAG_007     HON      active      0.1020  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.1113  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.1191  ACCEPT
#         C9   TAG_010     HON      active      0.1580  ACCEPT
#   -> Accepted 10/10 clients
#
#   Round  10: ACC=0.7603 | t_acc=0.9707 | o_acc=0.7079 | TPR=0.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : []
#     True Positives     : []
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : []
#     Round Time         : 127.56s
#
# [FIP] Round 20 | median=0.073954 | anchor=0.077403
#       dir_eps=0.000000 | global_bounds=(0.023221, 0.232209)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, bootstrap:1, pub_2+rescue:3, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0941, pub_2:0.0705, active:0.0533, pub_8:0.0774
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.018087, thresh=0.808706, delta=1.438351)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.4088  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0617  ACCEPT
#         C2   TAG_003     HON  pub_2+rescue      0.2877  ACCEPT
#         C3   TAG_004     HON      active      0.0292  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.0718  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0941  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0779  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0705  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0565  ACCEPT
#         C9   TAG_010     HON      active      0.0774  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  20: ACC=0.7584 | t_acc=0.9804 | o_acc=0.7059 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 140.35s
#
# [FIP] Round 30 | median=0.053439 | anchor=0.057026
#       dir_eps=-0.001922 | global_bounds=(0.017108, 0.171079)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_2+rescue:4, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0762, pub_2:0.0534, active:0.0570, pub_8:0.0570
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.160683, thresh=0.861260, delta=1.533683)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.3745  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0447  ACCEPT
#         C2   TAG_003     HON  pub_2+rescue      0.2609  ACCEPT
#         C3   TAG_004     HON      active      0.0172  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.0988  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0762  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0692  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0499  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0421  ACCEPT
#         C9   TAG_010     HON  pub_2+rescue      0.0570  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  30: ACC=0.7903 | t_acc=0.9804 | o_acc=0.7453 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 141.29s
#
# [FIP] Round 40 | median=0.051392 | anchor=0.057560
#       dir_eps=-0.001693 | global_bounds=(0.017268, 0.172679)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_2+rescue:4, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0650, pub_2:0.0514, active:0.0576, pub_8:0.0576
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.255790, thresh=0.896455, delta=1.604425)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.3545  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0339  ACCEPT
#         C2   TAG_003     HON  pub_2+rescue      0.2442  ACCEPT
#         C3   TAG_004     HON      active      0.0111  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.1159  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0650  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0592  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0452  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0350  ACCEPT
#         C9   TAG_010     HON  pub_2+rescue      0.0576  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  40: ACC=0.8140 | t_acc=0.9796 | o_acc=0.7754 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 139.54s
#
# [FIP] Round 50 | median=0.049461 | anchor=0.055751
#       dir_eps=-0.001906 | global_bounds=(0.016725, 0.167252)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_0+rescue:1, pub_2+rescue:3, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0587, pub_0:0.0558, active:0.0558, pub_8:0.0558, pub_2:0.0432
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.309702, thresh=0.916450, delta=1.639492)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.3420  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0342  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.2338  ACCEPT
#         C3   TAG_004     HON      active      0.0076  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.1262  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0587  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0580  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0432  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0266  ACCEPT
#         C9   TAG_010     HON  pub_2+rescue      0.0558  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  50: ACC=0.8264 | t_acc=0.9796 | o_acc=0.7908 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 140.06s
#
# [FIP] Round 60 | median=0.046018 | anchor=0.051741
#       dir_eps=-0.001283 | global_bounds=(0.015522, 0.155222)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_0+rescue:1, pub_2+rescue:3, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0550, pub_0:0.0517, active:0.0517, pub_8:0.0517, pub_2:0.0403
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.368297, thresh=0.938061, delta=1.685252)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.3309  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0352  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.2257  ACCEPT
#         C3   TAG_004     HON      active      0.0053  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.1343  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0550  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0517  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0403  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0312  ACCEPT
#         C9   TAG_010     HON  pub_2+rescue      0.0534  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  60: ACC=0.8358 | t_acc=0.9796 | o_acc=0.8028 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 140.88s
#
# [FIP] Round 70 | median=0.044164 | anchor=0.050111
#       dir_eps=-0.001488 | global_bounds=(0.015033, 0.150333)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_0+rescue:1, pub_2+rescue:3, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0522, pub_0:0.0501, active:0.0501, pub_8:0.0501, pub_2:0.0382
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.415225, thresh=0.950414, delta=1.719646)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.3253  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0324  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.2167  ACCEPT
#         C3   TAG_004     HON      active      0.0039  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.1419  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0522  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0501  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0382  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0262  ACCEPT
#         C9   TAG_010     HON  pub_2+rescue      0.0512  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  70: ACC=0.8424 | t_acc=0.9796 | o_acc=0.8112 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 140.40s
#
# [FIP] Round 80 | median=0.043150 | anchor=0.048343
#       dir_eps=-0.001385 | global_bounds=(0.014503, 0.145029)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_0+rescue:1, pub_2+rescue:3, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0483, pub_0:0.0483, active:0.0483, pub_8:0.0483, pub_2:0.0380
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.456110, thresh=0.965618, delta=1.751175)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.3154  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0323  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.2099  ACCEPT
#         C3   TAG_004     HON      active      0.0022  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.1472  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0483  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0515  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0380  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0263  ACCEPT
#         C9   TAG_010     HON  pub_2+rescue      0.0505  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  80: ACC=0.8487 | t_acc=0.9796 | o_acc=0.8192 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 140.25s
#
# [FIP] Round 90 | median=0.041958 | anchor=0.046800
#       dir_eps=-0.001462 | global_bounds=(0.014040, 0.140400)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_0+rescue:1, pub_2+rescue:3, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0468, pub_0:0.0468, active:0.0468, pub_8:0.0468, pub_2:0.0371
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.473757, thresh=0.971460, delta=1.763239)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.3109  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0340  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.2073  ACCEPT
#         C3   TAG_004     HON      active      0.0018  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.1502  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0468  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0479  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0371  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0207  ACCEPT
#         C9   TAG_010     HON  pub_2+rescue      0.0490  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  90: ACC=0.8534 | t_acc=0.9796 | o_acc=0.8246 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 140.32s
#
# [FIP] Round 100 | median=0.039570 | anchor=0.044221
#       dir_eps=-0.001342 | global_bounds=(0.013266, 0.132662)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0442, pub_0:0.1259, active:0.0442, pub_8:0.0442, pub_2:0.0284
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.510600, thresh=0.984230, delta=1.793073)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.3055  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0331  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.2032  ACCEPT
#         C3   TAG_004     HON      active      0.0012  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.1546  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0442  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0461  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0349  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0218  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0486  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 100: ACC=0.8568 | t_acc=0.9796 | o_acc=0.8289 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 140.65s
#
# [FIP] Round 110 | median=0.040091 | anchor=0.043085
#       dir_eps=-0.000750 | global_bounds=(0.012925, 0.129255)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0431, pub_0:0.1238, active:0.0431, pub_8:0.0431, pub_2:0.0295
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.538559, thresh=0.995088, delta=1.815582)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.3028  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0333  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.2009  ACCEPT
#         C3   TAG_004     HON      active      0.0007  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.1568  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0431  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0448  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0371  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0219  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0467  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 110: ACC=0.8601 | t_acc=0.9796 | o_acc=0.8326 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 140.17s
#
# [FIP] Round 120 | median=0.038290 | anchor=0.041609
#       dir_eps=-0.001052 | global_bounds=(0.012483, 0.124827)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0416, pub_0:0.1240, active:0.0416, pub_8:0.0416, pub_2:0.0252
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.565399, thresh=1.004666, delta=1.837871)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2978  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0338  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1975  ACCEPT
#         C3   TAG_004     HON      active      0.0002  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.1612  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0416  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0475  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0350  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0155  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0506  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 120: ACC=0.8631 | t_acc=0.9796 | o_acc=0.8365 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 140.31s
#
# [FIP] Round 130 | median=0.038107 | anchor=0.039661
#       dir_eps=-0.000789 | global_bounds=(0.011898, 0.118984)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0397, pub_0:0.1220, active:0.0397, pub_8:0.0397, pub_2:0.0288
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.584955, thresh=1.011939, delta=1.852900)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2973  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0331  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1965  ACCEPT
#         C3   TAG_004     HON      active     -0.0004  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.1631  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0397  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0465  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0366  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0211  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0475  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 130: ACC=0.8658 | t_acc=0.9796 | o_acc=0.8394 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 143.29s
#
# [FIP] Round 140 | median=0.038448 | anchor=0.039532
#       dir_eps=-0.000757 | global_bounds=(0.011859, 0.118595)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:1, bootstrap:1, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0395, pub_0:0.1180, active:0.0395, pub_8:0.0395, pub_2:0.0281
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.597212, thresh=1.019088, delta=1.864350)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2926  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0348  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1919  ACCEPT
#         C3   TAG_004     HON      active     -0.0004  ACCEPT
#         C4   TAG_005     MAL   bootstrap     -0.1640  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0395  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0439  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0374  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0189  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0441  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 140: ACC=0.8676 | t_acc=0.9796 | o_acc=0.8417 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 143.60s
#
# [FIP] Round 150 | median=0.037806 | anchor=0.039631
#       dir_eps=-0.000801 | global_bounds=(0.011889, 0.118893)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0396, pub_0:0.1180, active:0.0396, pub_8:0.0396, pub_2:0.0268
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.619189, thresh=1.024984, delta=1.881101)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2911  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0347  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1916  ACCEPT
#         C3   TAG_004     HON      active     -0.0007  ACCEPT
#         C4   TAG_005     MAL      active     -0.1657  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0396  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0424  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0360  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0177  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0444  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 150: ACC=0.8687 | t_acc=0.9787 | o_acc=0.8431 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 143.05s
#
# [FIP] Round 160 | median=0.034788 | anchor=0.036055
#       dir_eps=-0.000763 | global_bounds=(0.010817, 0.108165)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0361, pub_0:0.1181, pub_8:0.0361, pub_2:0.0269, active:0.0361
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.640113, thresh=1.033662, delta=1.899734)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2877  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0335  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1903  ACCEPT
#         C3   TAG_004     HON      active     -0.0008  ACCEPT
#         C4   TAG_005     MAL      active     -0.1643  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0361  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0406  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0333  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0205  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0459  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 160: ACC=0.8709 | t_acc=0.9787 | o_acc=0.8458 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 143.22s
#
# [FIP] Round 170 | median=0.036695 | anchor=0.037546
#       dir_eps=-0.000715 | global_bounds=(0.011264, 0.112639)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0375, pub_0:0.1159, active:0.0375, pub_8:0.0375, pub_2:0.0273
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.650086, thresh=1.037952, delta=1.908223)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2841  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0358  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1872  ACCEPT
#         C3   TAG_004     HON      active     -0.0005  ACCEPT
#         C4   TAG_005     MAL      active     -0.1628  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0375  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0425  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0338  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0209  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0447  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 170: ACC=0.8725 | t_acc=0.9778 | o_acc=0.8480 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 142.48s
#
# [FIP] Round 180 | median=0.034628 | anchor=0.034969
#       dir_eps=-0.000688 | global_bounds=(0.010491, 0.104906)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0350, pub_0:0.1146, active:0.0350, pub_8:0.0350, pub_2:0.0250
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.663903, thresh=1.041298, delta=1.919296)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2851  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0343  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1866  ACCEPT
#         C3   TAG_004     HON      active     -0.0006  ACCEPT
#         C4   TAG_005     MAL      active     -0.1629  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0350  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0421  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0304  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0197  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0426  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 180: ACC=0.8745 | t_acc=0.9778 | o_acc=0.8505 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 143.73s
#
# [FIP] Round 190 | median=0.035145 | anchor=0.035714
#       dir_eps=-0.000568 | global_bounds=(0.010714, 0.107142)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0357, pub_0:0.1154, pub_8:0.0357, pub_2:0.0299, active:0.0357
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.672546, thresh=1.046291, delta=1.927000)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2781  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0357  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1861  ACCEPT
#         C3   TAG_004     HON      active     -0.0008  ACCEPT
#         C4   TAG_005     MAL      active     -0.1612  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0346  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0399  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0340  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0258  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0448  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 190: ACC=0.8747 | t_acc=0.9778 | o_acc=0.8508 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 142.34s
#
# [FIP] Round 200 | median=0.034674 | anchor=0.035136
#       dir_eps=-0.000524 | global_bounds=(0.010541, 0.105409)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0351, pub_0:0.1139, pub_8:0.0351, pub_2:0.0290, active:0.0351
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.692803, thresh=1.051952, delta=1.941548)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2806  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0342  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1853  ACCEPT
#         C3   TAG_004     HON      active     -0.0011  ACCEPT
#         C4   TAG_005     MAL      active     -0.1612  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0351  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0417  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0331  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0249  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0424  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 200: ACC=0.8766 | t_acc=0.9778 | o_acc=0.8532 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 142.38s
#
# [FIP] Round 210 | median=0.034361 | anchor=0.034552
#       dir_eps=-0.000708 | global_bounds=(0.010366, 0.103656)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0346, pub_0:0.1133, pub_8:0.0346, pub_2:0.0250, active:0.0346
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.704343, thresh=1.057686, delta=1.952395)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2773  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0346  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1832  ACCEPT
#         C3   TAG_004     HON      active     -0.0010  ACCEPT
#         C4   TAG_005     MAL      active     -0.1611  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0342  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0419  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0303  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0198  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0434  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 210: ACC=0.8773 | t_acc=0.9778 | o_acc=0.8541 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 141.45s
#
# [FIP] Round 220 | median=0.035504 | anchor=0.035659
#       dir_eps=-0.000713 | global_bounds=(0.010698, 0.106977)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0357, pub_0:0.1123, pub_8:0.0357, pub_2:0.0277, active:0.0357
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.698204, thresh=1.055673, delta=1.946524)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2763  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0357  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1808  ACCEPT
#         C3   TAG_004     HON      active     -0.0009  ACCEPT
#         C4   TAG_005     MAL      active     -0.1590  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0343  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0421  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0353  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0200  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0437  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 220: ACC=0.8783 | t_acc=0.9778 | o_acc=0.8552 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 141.71s
#
# [FIP] Round 230 | median=0.034850 | anchor=0.036350
#       dir_eps=-0.000873 | global_bounds=(0.010905, 0.109050)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0363, pub_0:0.1133, pub_8:0.0363, pub_2:0.0228, active:0.0363
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.723320, thresh=1.065714, delta=1.969017)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2739  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0363  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1815  ACCEPT
#         C3   TAG_004     HON      active     -0.0010  ACCEPT
#         C4   TAG_005     MAL      active     -0.1583  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0333  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0448  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0296  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0160  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0451  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 230: ACC=0.8796 | t_acc=0.9778 | o_acc=0.8569 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 142.87s
#
# [FIP] Round 240 | median=0.033719 | anchor=0.035904
#       dir_eps=-0.001018 | global_bounds=(0.010771, 0.107713)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0359, pub_0:0.1117, pub_8:0.0359, pub_2:0.0216, active:0.0359
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.736167, thresh=1.070195, delta=1.980267)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2743  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0359  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1794  ACCEPT
#         C3   TAG_004     HON      active     -0.0011  ACCEPT
#         C4   TAG_005     MAL      active     -0.1581  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0315  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0474  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0297  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0135  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0440  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 240: ACC=0.8805 | t_acc=0.9778 | o_acc=0.8579 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 141.78s
#
# [FIP] Round 250 | median=0.032714 | anchor=0.033313
#       dir_eps=-0.000651 | global_bounds=(0.009994, 0.099939)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0333, pub_0:0.1108, pub_8:0.0333, pub_2:0.0264, active:0.0333
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.739771, thresh=1.068498, delta=1.980105)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2749  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0333  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1799  ACCEPT
#         C3   TAG_004     HON      active     -0.0009  ACCEPT
#         C4   TAG_005     MAL      active     -0.1572  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0321  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0431  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0314  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0214  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0417  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 250: ACC=0.8813 | t_acc=0.9778 | o_acc=0.8589 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 142.95s
#
# [FIP] Round 260 | median=0.033054 | anchor=0.033492
#       dir_eps=-0.000375 | global_bounds=(0.010048, 0.100475)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0335, pub_0:0.1123, pub_8:0.0335, pub_2:0.0263, active:0.0335
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.747696, thresh=1.070925, delta=1.986371)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2700  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0335  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1797  ACCEPT
#         C3   TAG_004     HON      active     -0.0012  ACCEPT
#         C4   TAG_005     MAL      active     -0.1559  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0303  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0373  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0326  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0199  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0450  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 260: ACC=0.8822 | t_acc=0.9778 | o_acc=0.8600 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 142.93s
#
# [FIP] Round 270 | median=0.034041 | anchor=0.035226
#       dir_eps=-0.000344 | global_bounds=(0.010568, 0.105678)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0352, pub_0:0.1093, pub_8:0.0352, pub_2:0.0252, active:0.0352
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.756510, thresh=1.077635, delta=1.995612)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2700  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0352  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1754  ACCEPT
#         C3   TAG_004     HON      active     -0.0011  ACCEPT
#         C4   TAG_005     MAL      active     -0.1554  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0329  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0422  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0299  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0204  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0433  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 270: ACC=0.8826 | t_acc=0.9778 | o_acc=0.8605 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 142.96s
#
# [FIP] Round 280 | median=0.032388 | anchor=0.032898
#       dir_eps=-0.000412 | global_bounds=(0.009870, 0.098695)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:2, pub_0+rescue:2, pub_2+rescue:2, pub_6+rescue:3, pub_8+rescue:1
#       ref_anchors=pub_6:0.0329, pub_0:0.1098, pub_8:0.0329, pub_2:0.0228, active:0.0329
#       [Stage 1T] Targeted source-margin detection: rejected 1 clients (gap=1.770740, thresh=1.079389, delta=2.005507)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_6+rescue      0.2703  ACCEPT
#         C1   TAG_002     HON  pub_6+rescue      0.0329  ACCEPT
#         C2   TAG_003     HON  pub_0+rescue      0.1764  ACCEPT
#         C3   TAG_004     HON      active     -0.0009  ACCEPT
#         C4   TAG_005     MAL      active     -0.1557  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON  pub_6+rescue      0.0319  ACCEPT
#         C6   TAG_007     HON  pub_8+rescue      0.0382  ACCEPT
#         C7   TAG_008     HON  pub_2+rescue      0.0298  ACCEPT
#         C8   TAG_009     HON  pub_2+rescue      0.0157  ACCEPT
#         C9   TAG_010     HON  pub_0+rescue      0.0432  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 280: ACC=0.8832 | t_acc=0.9778 | o_acc=0.8611 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 142.35s
#
# [FIP] Round 290 | median=0.032936 | anchor=0.034472
#       dir_eps=-0.000353 | global_bounds=(0.010342, 0.103417)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
# ...
#         C0   TAG_001     MAL   bootstrap     -0.0451  REJECT (Stage 1: Targeted Margin)
#         C1   TAG_002     HON   bootstrap      0.0232  ACCEPT
#         C2   TAG_003     MAL      active     -0.1508  REJECT (Stage 1: Targeted Margin)
#         C3   TAG_004     MAL      active     -0.1738  REJECT (Stage 1: Targeted Margin)
#         C4   TAG_005     MAL   bootstrap     -0.0491  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON      active      0.0107  ACCEPT
#         C6   TAG_007     HON      active      0.0089  ACCEPT
#         C7   TAG_008     HON   bootstrap      0.0139  ACCEPT
#         C8   TAG_009     HON      active     -0.0022  ACCEPT
#         C9   TAG_010     MAL      active     -0.1353  REJECT (Stage 1: Targeted Margin)
#   -> Accepted 5/10 clients
#
#   Round 220: ACC=0.8258 | t_acc=0.9804 | o_acc=0.7901 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Detected Malicious : ['C0', 'C2', 'C3', 'C4', 'C9']
#     True Positives     : ['C0', 'C2', 'C3', 'C4', 'C9']
#     False Positives    : []
#     Accepted Clients   : ['C1', 'C5', 'C6', 'C7', 'C8']
#     Rejected Clients   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Round Time         : 148.91s
#
# [FIP] Round 230 | median=-0.026114 | anchor=0.010721
#       dir_eps=-0.003839 | global_bounds=(0.000536, 0.160820)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:6, bootstrap:4
#       ref_anchors=bootstrap:0.0184, active:0.0090
#       [Stage 1T] Targeted source-margin detection: rejected 5 clients (gap=1.658959, thresh=1.050056, delta=1.941730)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL   bootstrap     -0.0508  REJECT (Stage 1: Targeted Margin)
#         C1   TAG_002     HON   bootstrap      0.0229  ACCEPT
#         C2   TAG_003     MAL      active     -0.1528  REJECT (Stage 1: Targeted Margin)
#         C3   TAG_004     MAL      active     -0.1743  REJECT (Stage 1: Targeted Margin)
#         C4   TAG_005     MAL   bootstrap     -0.0499  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON      active      0.0107  ACCEPT
#         C6   TAG_007     HON      active      0.0090  ACCEPT
#         C7   TAG_008     HON   bootstrap      0.0138  ACCEPT
#         C8   TAG_009     HON      active     -0.0024  ACCEPT
#         C9   TAG_010     MAL      active     -0.1368  REJECT (Stage 1: Targeted Margin)
#   -> Accepted 5/10 clients
#
#   Round 230: ACC=0.8261 | t_acc=0.9804 | o_acc=0.7905 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Detected Malicious : ['C0', 'C2', 'C3', 'C4', 'C9']
#     True Positives     : ['C0', 'C2', 'C3', 'C4', 'C9']
#     False Positives    : []
#     Accepted Clients   : ['C1', 'C5', 'C6', 'C7', 'C8']
#     Rejected Clients   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Round Time         : 148.47s
#
# [FIP] Round 240 | median=-0.024435 | anchor=0.010313
#       dir_eps=-0.003637 | global_bounds=(0.000516, 0.154690)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:6, bootstrap:4
#       ref_anchors=bootstrap:0.0181, active:0.0090
#       [Stage 1T] Targeted source-margin detection: rejected 5 clients (gap=1.654069, thresh=1.049505, delta=1.947651)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL   bootstrap     -0.0473  REJECT (Stage 1: Targeted Margin)
#         C1   TAG_002     HON   bootstrap      0.0226  ACCEPT
#         C2   TAG_003     MAL      active     -0.1535  REJECT (Stage 1: Targeted Margin)
#         C3   TAG_004     MAL      active     -0.1760  REJECT (Stage 1: Targeted Margin)
#         C4   TAG_005     MAL   bootstrap     -0.0468  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON      active      0.0103  ACCEPT
#         C6   TAG_007     HON      active      0.0090  ACCEPT
#         C7   TAG_008     HON   bootstrap      0.0136  ACCEPT
#         C8   TAG_009     HON      active     -0.0020  ACCEPT
#         C9   TAG_010     MAL      active     -0.1370  REJECT (Stage 1: Targeted Margin)
#   -> Accepted 5/10 clients
#
#   Round 240: ACC=0.8266 | t_acc=0.9804 | o_acc=0.7910 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Detected Malicious : ['C0', 'C2', 'C3', 'C4', 'C9']
#     True Positives     : ['C0', 'C2', 'C3', 'C4', 'C9']
#     False Positives    : []
#     Accepted Clients   : ['C1', 'C5', 'C6', 'C7', 'C8']
#     Rejected Clients   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Round Time         : 148.60s
#
# [FIP] Round 250 | median=-0.026827 | anchor=0.010070
#       dir_eps=-0.003846 | global_bounds=(0.000503, 0.151044)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:6, bootstrap:4
#       ref_anchors=bootstrap:0.0176, active:0.0083
#       [Stage 1T] Targeted source-margin detection: rejected 5 clients (gap=1.674815, thresh=1.054038, delta=1.960605)
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL   bootstrap     -0.0524  REJECT (Stage 1: Targeted Margin)
#         C1   TAG_002     HON   bootstrap      0.0221  ACCEPT
#         C2   TAG_003     MAL      active     -0.1526  REJECT (Stage 1: Targeted Margin)
#         C3   TAG_004     MAL      active     -0.1742  REJECT (Stage 1: Targeted Margin)
#         C4   TAG_005     MAL   bootstrap     -0.0506  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON      active      0.0101  ACCEPT
#         C6   TAG_007     HON      active      0.0083  ACCEPT
#         C7   TAG_008     HON   bootstrap      0.0132  ACCEPT
#         C8   TAG_009     HON      active     -0.0030  ACCEPT
#         C9   TAG_010     MAL      active     -0.1393  REJECT (Stage 1: Targeted Margin)
#   -> Accepted 5/10 clients
#
#   Round 250: ACC=0.8267 | t_acc=0.9804 | o_acc=0.7913 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Detected Malicious : ['C0', 'C2', 'C3', 'C4', 'C9']
#     True Positives     : ['C0', 'C2', 'C3', 'C4', 'C9']
#     False Positives    : []
#     Accepted Clients   : ['C1', 'C5', 'C6', 'C7', 'C8']
#     Rejected Clients   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Round Time         : 148.84s
#
# [FIP] Round 260 | median=-0.025670 | anchor=0.010065
#       dir_eps=-0.001865 | global_bounds=(0.000503, 0.150979)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:6, bootstrap:4
#       ref_anchors=bootstrap:0.0176, active:0.0084
#       [Stage 1T] Targeted source-margin detection: rejected 5 clients (gap=1.684569, thresh=1.061855, delta=1.964115)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL   bootstrap     -0.0483  REJECT (Stage 1: Targeted Margin)
#         C1   TAG_002     HON   bootstrap      0.0219  ACCEPT
#         C2   TAG_003     MAL      active     -0.1537  REJECT (Stage 1: Targeted Margin)
#         C3   TAG_004     MAL      active     -0.1751  REJECT (Stage 1: Targeted Margin)
#         C4   TAG_005     MAL   bootstrap     -0.0528  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON      active      0.0101  ACCEPT
#         C6   TAG_007     HON      active      0.0084  ACCEPT
#         C7   TAG_008     HON   bootstrap      0.0132  ACCEPT
#         C8   TAG_009     HON      active     -0.0031  ACCEPT
#         C9   TAG_010     MAL      active     -0.1385  REJECT (Stage 1: Targeted Margin)
#   -> Accepted 5/10 clients
#
#   Round 260: ACC=0.8267 | t_acc=0.9804 | o_acc=0.7911 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Detected Malicious : ['C0', 'C2', 'C3', 'C4', 'C9']
#     True Positives     : ['C0', 'C2', 'C3', 'C4', 'C9']
#     False Positives    : []
#     Accepted Clients   : ['C1', 'C5', 'C6', 'C7', 'C8']
#     Rejected Clients   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Round Time         : 148.95s
#
# [FIP] Round 270 | median=-0.026802 | anchor=0.009725
#       dir_eps=-0.001915 | global_bounds=(0.000486, 0.145880)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:6, bootstrap:4
#       ref_anchors=bootstrap:0.0173, active:0.0081
#       [Stage 1T] Targeted source-margin detection: rejected 5 clients (gap=1.694418, thresh=1.064498, delta=1.977688)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL   bootstrap     -0.0504  REJECT (Stage 1: Targeted Margin)
#         C1   TAG_002     HON   bootstrap      0.0213  ACCEPT
#         C2   TAG_003     MAL      active     -0.1555  REJECT (Stage 1: Targeted Margin)
#         C3   TAG_004     MAL      active     -0.1761  REJECT (Stage 1: Targeted Margin)
#         C4   TAG_005     MAL   bootstrap     -0.0514  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON      active      0.0097  ACCEPT
#         C6   TAG_007     HON      active      0.0081  ACCEPT
#         C7   TAG_008     HON   bootstrap      0.0133  ACCEPT
#         C8   TAG_009     HON      active     -0.0032  ACCEPT
#         C9   TAG_010     MAL      active     -0.1397  REJECT (Stage 1: Targeted Margin)
#   -> Accepted 5/10 clients
#
#   Round 270: ACC=0.8270 | t_acc=0.9804 | o_acc=0.7917 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Detected Malicious : ['C0', 'C2', 'C3', 'C4', 'C9']
#     True Positives     : ['C0', 'C2', 'C3', 'C4', 'C9']
#     False Positives    : []
#     Accepted Clients   : ['C1', 'C5', 'C6', 'C7', 'C8']
#     Rejected Clients   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Round Time         : 149.38s
#
# [FIP] Round 280 | median=-0.025211 | anchor=0.009700
#       dir_eps=-0.001826 | global_bounds=(0.000485, 0.145507)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:6, bootstrap:4
#       ref_anchors=bootstrap:0.0172, active:0.0078
#       [Stage 1T] Targeted source-margin detection: rejected 5 clients (gap=1.691851, thresh=1.062805, delta=1.982182)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL   bootstrap     -0.0508  REJECT (Stage 1: Targeted Margin)
#         C1   TAG_002     HON   bootstrap      0.0215  ACCEPT
#         C2   TAG_003     MAL      active     -0.1549  REJECT (Stage 1: Targeted Margin)
#         C3   TAG_004     MAL      active     -0.1776  REJECT (Stage 1: Targeted Margin)
#         C4   TAG_005     MAL   bootstrap     -0.0478  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON      active      0.0097  ACCEPT
#         C6   TAG_007     HON      active      0.0078  ACCEPT
#         C7   TAG_008     HON   bootstrap      0.0129  ACCEPT
#         C8   TAG_009     HON      active     -0.0026  ACCEPT
#         C9   TAG_010     MAL      active     -0.1392  REJECT (Stage 1: Targeted Margin)
#   -> Accepted 5/10 clients
#
#   Round 280: ACC=0.8274 | t_acc=0.9804 | o_acc=0.7922 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Detected Malicious : ['C0', 'C2', 'C3', 'C4', 'C9']
#     True Positives     : ['C0', 'C2', 'C3', 'C4', 'C9']
#     False Positives    : []
#     Accepted Clients   : ['C1', 'C5', 'C6', 'C7', 'C8']
#     Rejected Clients   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Round Time         : 148.60s
#
# [FIP] Round 290 | median=-0.026672 | anchor=0.009486
#       dir_eps=-0.001889 | global_bounds=(0.000474, 0.142290)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:6, bootstrap:4
#       ref_anchors=bootstrap:0.0168, active:0.0082
#       [Stage 1T] Targeted source-margin detection: rejected 5 clients (gap=1.703743, thresh=1.070531, delta=1.982936)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL   bootstrap     -0.0499  REJECT (Stage 1: Targeted Margin)
#         C1   TAG_002     HON   bootstrap      0.0208  ACCEPT
#         C2   TAG_003     MAL      active     -0.1546  REJECT (Stage 1: Targeted Margin)
#         C3   TAG_004     MAL      active     -0.1779  REJECT (Stage 1: Targeted Margin)
#         C4   TAG_005     MAL   bootstrap     -0.0540  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON      active      0.0095  ACCEPT
#         C6   TAG_007     HON      active      0.0082  ACCEPT
#         C7   TAG_008     HON   bootstrap      0.0127  ACCEPT
#         C8   TAG_009     HON      active     -0.0035  ACCEPT
#         C9   TAG_010     MAL      active     -0.1392  REJECT (Stage 1: Targeted Margin)
#   -> Accepted 5/10 clients
#
#   Round 290: ACC=0.8273 | t_acc=0.9804 | o_acc=0.7920 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Detected Malicious : ['C0', 'C2', 'C3', 'C4', 'C9']
#     True Positives     : ['C0', 'C2', 'C3', 'C4', 'C9']
#     False Positives    : []
#     Accepted Clients   : ['C1', 'C5', 'C6', 'C7', 'C8']
#     Rejected Clients   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Round Time         : 148.80s
#
# [FIP] Round 300 | median=-0.027030 | anchor=0.009317
#       dir_eps=-0.001897 | global_bounds=(0.000466, 0.139748)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:6, bootstrap:4
#       ref_anchors=bootstrap:0.0166, active:0.0077
#       [Stage 1T] Targeted source-margin detection: rejected 5 clients (gap=1.707065, thresh=1.068982, delta=1.991946)
#       [Stage 1R] Honest-safe rescue: restored 1 clients
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL   bootstrap     -0.0505  REJECT (Stage 1: Targeted Margin)
#         C1   TAG_002     HON   bootstrap      0.0207  ACCEPT
#         C2   TAG_003     MAL      active     -0.1566  REJECT (Stage 1: Targeted Margin)
#         C3   TAG_004     MAL      active     -0.1784  REJECT (Stage 1: Targeted Margin)
#         C4   TAG_005     MAL   bootstrap     -0.0513  REJECT (Stage 1: Targeted Margin)
#         C5   TAG_006     HON      active      0.0093  ACCEPT
#         C6   TAG_007     HON      active      0.0077  ACCEPT
#         C7   TAG_008     HON   bootstrap      0.0125  ACCEPT
#         C8   TAG_009     HON      active     -0.0036  ACCEPT
#         C9   TAG_010     MAL      active     -0.1403  REJECT (Stage 1: Targeted Margin)
#   -> Accepted 5/10 clients
#
#   Round 300: ACC=0.8276 | t_acc=0.9804 | o_acc=0.7924 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Detected Malicious : ['C0', 'C2', 'C3', 'C4', 'C9']
#     True Positives     : ['C0', 'C2', 'C3', 'C4', 'C9']
#     False Positives    : []
#     Accepted Clients   : ['C1', 'C5', 'C6', 'C7', 'C8']
#     Rejected Clients   : ['C0', 'C2', 'C3', 'C4', 'C9']
#     Round Time         : 149.12s
# [CSV] Saved 1200 rows to 'codex_noniid_targeted_all_round_results.csv'
# ============================================================
#  FINAL RESULTS ACROSS ALL SEEDS
# ============================================================
#
# Attack Rate 10%:
#   Overall Accuracy : 0.8854 ± 0.0000
#   Target Accuracy  : 0.9769 ± 0.0000
#
# Attack Rate 20%:
#   Overall Accuracy : 0.8979 ± 0.0000
#   Target Accuracy  : 0.9787 ± 0.0000
#
# Attack Rate 30%:
#   Overall Accuracy : 0.8327 ± 0.0000
#   Target Accuracy  : 0.9716 ± 0.0000
#
# Attack Rate 50%:
#   Overall Accuracy : 0.8276 ± 0.0000
#   Target Accuracy  : 0.9804 ± 0.0000
