# %% [markdown]
# # Complete final file
# # This is an IID setting with an untargeted label-flipping attack.

# %%
pip install phe

# %%
"""
FIP-based PPFL: MNIST Experiment (Thesis Architecture) - FINAL VERSION
------------------------------------------------------------------------
[Setting] IID data distribution + Untargeted Label Flip (y+5)%10

Key updates in this version:
1. auth reset per attack_rate (TAG registry fix)
2. SCALE-INVARIANT scoring via reference-norm normalization
3. Relative bounds with positive-anchor median (reduces median poisoning impact)
4. Restored Stage 1 directional check with tolerance (convergence-safe)
5. Dynamic history std floor + adaptive Z-threshold (late-round stability)
6. No forced-accept fallback (empty rounds are safely skipped)
7. TPR/FPR computed every round
8. Full MNIST dataset
9. Untargeted Label Flipping attack (y+5)%10
10. Relaxed early-round bounds
11. ROC tracking with -score
12. CSV export + plots
13. Multi-seed statistical runs
"""

import os
import sys
import time
import numpy as np
import copy
from concurrent.futures import ProcessPoolExecutor
import multiprocessing
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc
import matplotlib.pyplot as plt
import pandas as pd

# ============================================================
# 1. AUTO-GENERATE WORKER FILE (Fixes Jupyter Multiprocessing)
# ============================================================
worker_script = """
import math
import numpy as np
from phe import paillier

class MockCiphertext:
    def __init__(self, value): self.value = value
    def __add__(self, other): return MockCiphertext(self.value + other.value)
    def __mul__(self, other): return MockCiphertext(self.value * other)

class MockKey:
    def encrypt(self, value): return MockCiphertext(value)
    def decrypt(self, ciphertext): return ciphertext.value

def _safe_encrypt_int(pub_key, value, max_retries=16):
    if not hasattr(pub_key, 'nsquare'):
        return pub_key.encrypt(int(value))
    for _ in range(max_retries):
        enc = pub_key.encrypt(int(value))
        if math.gcd(int(enc.ciphertext(False)), int(pub_key.nsquare)) == 1:
            return enc
    raise ZeroDivisionError('Failed to sample an invertible Paillier ciphertext')

def _encrypt_chunk(args):
    pub_key, chunk = args
    return [_safe_encrypt_int(pub_key, x) for x in chunk]

def _decrypt_chunk(args):
    priv_key, chunk = args
    return [priv_key.decrypt(x) for x in chunk]

def _calc_score_worker(args):
    enc_chunk, ref_int_chunk = args
    if len(enc_chunk) == 0: return 0
    partial_sum = enc_chunk[0] * ref_int_chunk[0]
    for i in range(1, len(enc_chunk)):
        partial_sum = partial_sum + (enc_chunk[i] * ref_int_chunk[i])
    return partial_sum

def _train_client_worker(args):
    c_id, X, y, W_init, b_init, is_malicious, num_classes, input_dim, pub_key, scale, lr, batch, epochs = args

    W = W_init.copy()
    b = b_init.copy()
    prev_W = W.copy()
    prev_b = b.copy()
    y_train = y.copy()

    if is_malicious:
        # UNTARGETED LABEL FLIPPING ATTACK
        y_train = (y_train + 5) % 10

    indices = np.arange(len(X))

    def softmax(z):
        exp_z = np.exp(z - np.max(z, axis=1, keepdims=True))
        return exp_z / exp_z.sum(axis=1, keepdims=True)

    for _ in range(epochs):
        np.random.shuffle(indices)
        for start in range(0, len(X), batch):
            end = start + batch
            idx = indices[start:end]
            if len(idx) == 0:
                continue

            X_b, y_b = X[idx], y_train[idx]
            scores = np.dot(X_b, W) + b
            probs = softmax(scores)
            y_oh = np.zeros((len(y_b), num_classes))
            y_oh[np.arange(len(y_b)), y_b] = 1
            error = probs - y_oh
            grad_W = np.dot(X_b.T, error) / len(X_b)
            grad_b = np.mean(error, axis=0)
            W -= lr * grad_W
            b -= lr * grad_b

    update_W = prev_W - W
    update_b = prev_b - b

    model_update = np.concatenate([update_W.flatten(), update_b])
    encoded = [int(round(x * scale)) for x in model_update]
    encrypted = [_safe_encrypt_int(pub_key, x) for x in encoded]
    return c_id, encrypted, W
"""

with open("fip_workers_iid_untargeted.py", "w") as f:
    f.write(worker_script)

from fip_workers_iid_untargeted import (
    _encrypt_chunk, _decrypt_chunk, _calc_score_worker,
    _train_client_worker, MockKey, MockCiphertext
)

# ============================================================
# CONFIGURATION
# ============================================================
SEEDS = [123]
all_results = {}

N_ROUNDS = 300
N_CLIENTS = 10
BATCH_SIZE = 50
LEARNING_RATE = 0.01
LOCAL_EPOCHS = 1
USE_REAL_ENCRYPTION = True
FIXED_POINT_SCALE = 10000
ATTACK_RATES = [0.1, 0.2, 0.3, 0.5]

NUM_CORES = max(1, int(multiprocessing.cpu_count() * 0.90))

# ============================================================
# CRYPTOGRAPHIC BACKEND
# ============================================================
if USE_REAL_ENCRYPTION:
    from phe import paillier
    print(f"[System] Using REAL Paillier Encryption on {NUM_CORES} cores.")
else:
    print("[System] Using SIMULATED Encryption (Fast).")

print("[Setting] IID data distribution + Untargeted Label Flip (y+5)%10")


class FixedPoint:
    def __init__(self, scale=FIXED_POINT_SCALE):
        self.scale = scale

    def encode(self, x):
        return int(round(x * self.scale))

    def decode(self, x):
        return float(x) / self.scale

    def decode_squared(self, x):
        return float(x) / (self.scale ** 2)

    def enc_vec(self, pub, vec):
        if not USE_REAL_ENCRYPTION:
            return [pub.encrypt(self.encode(v)) for v in vec]
        encoded_vec = [self.encode(v) for v in vec]
        chunk_size = max(1, len(encoded_vec) // NUM_CORES + 1)
        chunks = [encoded_vec[i:i + chunk_size] for i in range(0, len(encoded_vec), chunk_size)]
        with ProcessPoolExecutor(max_workers=NUM_CORES) as executor:
            results = list(executor.map(_encrypt_chunk, [(pub, c) for c in chunks]))
        return [item for sublist in results for item in sublist]

    def dec_vec(self, priv, enc_vec):
        if not USE_REAL_ENCRYPTION:
            return np.array([self.decode(priv.decrypt(c)) for c in enc_vec])
        chunk_size = max(1, len(enc_vec) // NUM_CORES + 1)
        chunks = [enc_vec[i:i + chunk_size] for i in range(0, len(enc_vec), chunk_size)]
        with ProcessPoolExecutor(max_workers=NUM_CORES) as executor:
            results = list(executor.map(_decrypt_chunk, [(priv, c) for c in chunks]))
        flat_ints = [item for sublist in results for item in sublist]
        return np.array([self.decode(x) for x in flat_ints])


# ============================================================
# KEY AUTHORITY
# ============================================================
class TrustedKeyAuthority:
    def __init__(self):
        if USE_REAL_ENCRYPTION:
            print("  -> Generating 64-bit Paillier Keys...")
            self.pub_key, self.priv_key = paillier.generate_paillier_keypair(n_length=64)
        else:
            self.pub_key, self.priv_key = MockKey(), MockKey()
        self.registry = {}

    def register_user(self, real_id):
        tag_id = f"TAG_{len(self.registry) + 1:03d}"
        self.registry[tag_id] = real_id
        return tag_id

    def distribute_keys(self):
        return self.pub_key, self.priv_key

    def get_registry_snapshot(self):
        return self.registry.copy()


# ============================================================
# DATA MANAGER  (IID)
# ============================================================
class DataManager:
    def __init__(self, n_clients):
        print("[Data] Downloading/Loading MNIST (70k samples)...")
        X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
        X = X / 255.0
        y = y.astype(int)

        X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=10000, random_state=42, stratify=y)
        X_priv, X_pub, y_priv, y_pub = train_test_split(
            X_train, y_train, test_size=5000, random_state=42, stratify=y_train)

        self.test_data = (X_test, y_test)
        self.public_data = (X_pub, y_pub)
        self.client_data = {}
        self.X_priv = X_priv
        self.y_priv = y_priv

        print(f"[Data] Train={len(X_priv)}, Public={len(X_pub)}, Test={len(X_test)}")
        print(f"[Data] Distributing IID to {n_clients} clients (all 10 classes each)...")
        self.create_iid_split(n_clients)

    def create_iid_split(self, n_clients):
        indices = np.arange(len(self.X_priv))
        np.random.shuffle(indices)
        chunks = np.array_split(indices, n_clients)
        for i in range(n_clients):
            self.client_data[i] = (self.X_priv[chunks[i]], self.y_priv[chunks[i]])

    def get_public_data(self):
        return self.public_data

    def get_test_data(self):
        return self.test_data

    def get_client_data(self, i):
        return self.client_data[i]

    def get_input_shape(self):
        return self.public_data[0].shape[1]


# ============================================================
# FIP VERIFIER
# ============================================================
class FIPVerifier:
    def __init__(self, key_authority, data_manager, input_dim, num_classes=10, attack_rate=0.0):
        print("[System] Initializing FIP Verifier...")
        self.pub, self.priv = key_authority.distribute_keys()
        self.key_authority = key_authority
        self.attack_rate = attack_rate
        self.fp = FixedPoint()
        self.update_table = {}
        self.client_history = {}
        self.alpha_ref = 0.8
        self.reference_bank = self._bootstrap_references(data_manager, input_dim, num_classes)
        self.bootstrap_ref = self.reference_bank["bootstrap"].copy()
        self.ref_directions = [self.bootstrap_ref.copy()]
        self.last_stable_ref = self.bootstrap_ref.copy()
        self.last_acceptance_ratio = 1.0
        self.empty_rounds = 0
        self.prev_anchor = 1e-2
        self.prev_anchor_by_ref = {}
        self.last_reference_source = "bootstrap"
        self.last_ref_usage = {}
        self.last_stage1_pass_count = 0
        self.last_stage1_fail_count = 0
        self.last_round_size = 0
        self.last_raw_median = 0.0
        self.last_positive_median = 0.0
        self.last_direction_eps = 0.0
        self.collapse_streak = 0

        self.roc_scores = []
        self.roc_labels = []

    def _normalize_reference(self, ref_grad):
        norm = np.linalg.norm(ref_grad)
        if norm > 1e-12:
            return ref_grad / norm
        return ref_grad.copy()

    def _compute_public_reference(self, X, y, num_classes):
        if len(X) == 0:
            return None
        y_onehot = np.zeros((len(y), num_classes))
        y_onehot[np.arange(len(y)), y] = 1
        probs = np.full((len(y), num_classes), 0.1)
        grad_W = np.dot(X.T, (probs - y_onehot)) / len(X)
        grad_b = np.mean(probs - y_onehot, axis=0)
        primary = np.concatenate([grad_W.flatten(), grad_b])
        return self._normalize_reference(primary)

    def _bootstrap_references(self, data_manager, input_dim, num_classes):
        X, y = data_manager.get_public_data()
        refs = {}
        refs["bootstrap"] = self._compute_public_reference(X, y, num_classes)
        for start in range(0, num_classes, 2):
            window = [(start + k) % num_classes for k in range(5)]
            mask = np.isin(y, window)
            ref = self._compute_public_reference(X[mask], y[mask], num_classes)
            if ref is not None:
                refs[f"pub_{start}"] = ref
        return refs

    def receive_update(self, tag_id, enc_gradient):
        self.update_table[tag_id] = enc_gradient

    def _homomorphic_inner_product_parallel(self, enc_grad, ref_grad):
        ref_ints = [self.fp.encode(x) for x in ref_grad]
        if not USE_REAL_ENCRYPTION:
            total = enc_grad[0] * ref_ints[0]
            for i in range(1, len(enc_grad)):
                total = total + (enc_grad[i] * ref_ints[i])
            return total

        chunk_size = max(1, len(enc_grad) // NUM_CORES + 1)
        enc_chunks = [enc_grad[i:i + chunk_size] for i in range(0, len(enc_grad), chunk_size)]
        ref_chunks = [ref_ints[i:i + chunk_size] for i in range(0, len(ref_ints), chunk_size)]
        if len(enc_chunks) != len(ref_chunks):
            ref_chunks = ref_chunks[:len(enc_chunks)]

        with ProcessPoolExecutor(max_workers=NUM_CORES) as executor:
            partial_results = list(executor.map(_calc_score_worker, zip(enc_chunks, ref_chunks)))

        total = partial_results[0]
        for i in range(1, len(partial_results)):
            total = total + partial_results[i]
        return total

    def _history_key(self, tid, ref_name):
        ref_key = ref_name.split('+', 1)[0]
        return (tid, ref_key)

    def _check_consistency(self, history_key, current_score, round_num):
        if round_num < 50:
            return True, "Warmup"
        if history_key not in self.client_history or len(self.client_history[history_key]) < 5:
            return True, "Building"

        prev = self.client_history[history_key]
        mean = np.mean(prev)
        std_floor = max(1e-3, 0.15 * max(abs(mean), 1e-3))
        std = max(np.std(prev), std_floor)
        z = abs(current_score - mean) / std

        z_th = 8.0 if abs(mean) > 0.01 else 12.0
        if z > z_th:
            return False, f"Z={z:.2f} > {z_th:.1f}"
        return True, "OK"

    def _compute_direction_eps(self, round_num, noise_scale):
        if self.attack_rate >= 0.5:
            if round_num < 20:
                return 0.0
            if round_num < 100:
                return -min(0.15 * noise_scale, 0.03)
            if round_num < 250:
                return -min(0.10 * noise_scale, 0.01)
            return -min(0.05 * noise_scale, 0.005)
        if round_num < 20:
            return 0.0
        if round_num < 100:
            return -min(0.10 * noise_scale, 5e-3)
        if round_num < 250:
            return -min(0.06 * noise_scale, 2e-3)
        return -min(0.03 * noise_scale, 5e-4)

    def _score_clients_for_reference(self, tag_ids, ref_grad):
        ref_norm = max(np.linalg.norm(ref_grad), 1e-12)
        scores_map = {}
        for tid in tag_ids:
            enc_grad = self.update_table[tid]
            enc_score = self._homomorphic_inner_product_parallel(enc_grad, ref_grad)
            raw = self.priv.decrypt(enc_score)
            scores_map[tid] = self.fp.decode_squared(raw) / ref_norm
        return scores_map

    def _build_reference_candidates(self):
        candidates = [("active", self.ref_directions[0])]
        if self.last_stable_ref is not None:
            candidates.append(("stable", self.last_stable_ref))
        for name, ref in self.reference_bank.items():
            candidates.append((name, ref))
        return candidates

    def _score_clients_multi_reference(self, tag_ids, round_num, direction_eps, noise_scale):
        core_names = {"active", "stable", "bootstrap"}
        per_ref_scores = {tid: {} for tid in tag_ids}
        for ref_name, ref_grad in self._build_reference_candidates():
            scores_map = self._score_clients_for_reference(tag_ids, ref_grad)
            for tid, score in scores_map.items():
                per_ref_scores[tid][ref_name] = score

        fused_scores = {}
        best_refs = {}
        ref_usage = {}
        rescue_margin = max(2.0 * noise_scale, 1e-3)

        tie_mode = (self.attack_rate >= 0.5)

        if not tie_mode:
            normal_regime = (
                self.last_round_size > 0 and
                self.last_acceptance_ratio >= 0.60 and
                self.last_stage1_pass_count >= max(6, int(np.ceil(0.60 * self.last_round_size)))
            )
            rescue_slack = max(2.0 * noise_scale, 1e-2)

        for tid, score_map in per_ref_scores.items():
            core_pairs = [(name, score) for name, score in score_map.items() if name in core_names]
            aux_pairs = [(name, score) for name, score in score_map.items() if name not in core_names]
            core_name, core_score = max(core_pairs, key=lambda kv: kv[1]) if core_pairs else ("active", -np.inf)
            core_scores = np.array([score for _, score in core_pairs], dtype=float) if core_pairs else np.array([], dtype=float)
            core_positive = int(np.sum(core_scores > direction_eps)) if len(core_scores) > 0 else 0
            core_median = float(np.median(core_scores)) if len(core_scores) > 0 else -np.inf
            aux_pairs.sort(key=lambda kv: kv[1], reverse=True)
            aux_name, aux_best = aux_pairs[0] if aux_pairs else (core_name, core_score)
            aux_second = aux_pairs[1][1] if len(aux_pairs) > 1 else -np.inf

            fused_score = core_score
            chosen_ref = core_name

            strict_core_pass = (core_score > direction_eps) and (core_positive >= 2) and (core_median > direction_eps)

            if tie_mode:
                core_pass = strict_core_pass
            else:
                soft_core_pass = (
                    normal_regime and
                    core_score > (direction_eps - rescue_slack) and
                    core_median > (direction_eps - rescue_slack)
                )
                core_pass = strict_core_pass or soft_core_pass

            if core_pass and aux_best > max(direction_eps, 0.0) and aux_second > max(direction_eps, 0.0) and aux_best > (core_score + rescue_margin):
                fused_score = min(aux_best, aux_second)
                chosen_ref = f"{aux_name}+rescue"

            fused_scores[tid] = fused_score
            best_refs[tid] = chosen_ref
            ref_usage[chosen_ref] = ref_usage.get(chosen_ref, 0) + 1

        return fused_scores, best_refs, ref_usage

    def perform_fip_audit(self, round_num, mal_tags):
        tag_ids = list(self.update_table.keys())
        if not tag_ids:
            return {}

        prelim_scores = self._score_clients_for_reference(tag_ids, self.ref_directions[0])
        prelim_vals = np.array(list(prelim_scores.values()), dtype=float)
        prelim_median = float(np.median(prelim_vals))
        prelim_mad = float(np.median(np.abs(prelim_vals - prelim_median)))
        noise_scale = max(prelim_mad, 1e-4)
        direction_eps = self._compute_direction_eps(round_num, noise_scale)

        scores_map, best_ref_map, ref_usage = self._score_clients_multi_reference(tag_ids, round_num, direction_eps, noise_scale)
        vals = np.array(list(scores_map.values()), dtype=float)
        raw_median = float(np.median(vals))
        raw_mad = float(np.median(np.abs(vals - raw_median)))
        noise_scale = max(raw_mad, 1e-4)
        direction_eps = self._compute_direction_eps(round_num, noise_scale)

        stage1_pass = {}
        stage1_fail = {}
        for tid, score in scores_map.items():
            if score <= direction_eps:
                stage1_fail[tid] = score
            else:
                stage1_pass[tid] = score

        survivor_ratio = len(stage1_pass) / max(len(tag_ids), 1)
        collapse_detected = (
            survivor_ratio < 0.5 and
            raw_median <= direction_eps
        )
        self.collapse_streak = (self.collapse_streak + 1) if collapse_detected else 0

        if len(stage1_pass) >= 3:
            anchor = float(np.median(np.array(list(stage1_pass.values()), dtype=float)))
        else:
            pos_all = vals[vals > direction_eps]
            if len(pos_all) >= 3:
                anchor = float(np.median(pos_all))
            elif len(pos_all) > 0:
                anchor = float(np.mean(pos_all))
            else:
                anchor = self.prev_anchor

        anchor_floor = max(1e-3, 0.25 * self.prev_anchor)
        anchor = max(anchor, anchor_floor)
        self.prev_anchor = anchor

        if round_num < 10:
            min_ratio, max_ratio = 0.10, 10.0
        elif survivor_ratio < 0.5:
            min_ratio, max_ratio = 0.02, 25.0
        elif survivor_ratio < 0.7:
            min_ratio, max_ratio = 0.05, 15.0
        else:
            min_ratio, max_ratio = 0.30, 3.0

        ref_group_scores = {}
        for tid, score in stage1_pass.items():
            ref_key = best_ref_map[tid].split('+', 1)[0]
            ref_group_scores.setdefault(ref_key, []).append(score)

        ref_group_bounds = {}
        ref_anchor_parts = []
        for ref_key, ref_scores in ref_group_scores.items():
            ref_arr = np.array(ref_scores, dtype=float)
            if len(ref_arr) >= 2:
                ref_anchor = float(np.median(ref_arr))
            else:
                ref_anchor = float(ref_arr[0])

            prev_group_anchor = self.prev_anchor_by_ref.get(ref_key, anchor)
            group_floor = max(1e-3, 0.10 * prev_group_anchor, 0.05 * anchor)
            ref_anchor = max(ref_anchor, group_floor)
            self.prev_anchor_by_ref[ref_key] = ref_anchor

            ref_spread = float(np.median(np.abs(ref_arr - np.median(ref_arr)))) if len(ref_arr) >= 2 else 0.0

            if len(ref_arr) <= 4:
                group_min_ratio = min(min_ratio, 0.10)
                group_max_ratio = max(max_ratio, 10.0)
            else:
                group_min_ratio = min_ratio
                group_max_ratio = max_ratio

            min_acc = ref_anchor * group_min_ratio
            max_acc = ref_anchor * group_max_ratio
            tiny_anchor = ref_anchor < max(0.02, 0.15 * anchor)
            if tiny_anchor:
                min_acc = min(min_acc, max(direction_eps, -0.001))
                max_acc = max(max_acc, float(np.max(ref_arr)) + max(3.0 * ref_spread, 0.01))

            ref_group_bounds[ref_key] = {
                'anchor': ref_anchor,
                'min_ratio': group_min_ratio,
                'max_ratio': group_max_ratio,
                'min_acc': min_acc,
                'max_acc': max_acc,
                'count': len(ref_arr),
            }
            ref_anchor_parts.append(f"{ref_key}:{ref_anchor:.4f}")

        default_bounds = {
            'anchor': anchor,
            'min_ratio': min_ratio,
            'max_ratio': max_ratio,
            'min_acc': anchor * min_ratio,
            'max_acc': anchor * max_ratio,
            'count': len(stage1_pass),
        }

        registry = self.key_authority.get_registry_snapshot()
        accepted = set()
        verbose_round = ((round_num + 1) % 10 == 0)

        if verbose_round:
            ref_mix = ', '.join(f"{name}:{count}" for name, count in sorted(ref_usage.items()))
            ref_anchor_summary = ', '.join(ref_anchor_parts) if ref_anchor_parts else 'none'
            print(f"\n[FIP] Round {round_num + 1} | median={raw_median:.6f} | anchor={anchor:.6f}")
            print(f"      dir_eps={direction_eps:.6f} | global_bounds=({default_bounds['min_acc']:.6f}, {default_bounds['max_acc']:.6f})")
            print(f"      ratios=({min_ratio:.2f}x, {max_ratio:.2f}x) | collapse_streak={self.collapse_streak}")
            print(f"      stage1_pass={len(stage1_pass)} | stage1_fail={len(stage1_fail)} | ref_mix={ref_mix}")
            print(f"      ref_anchors={ref_anchor_summary}")
            print(f"  {'Client':>8}  {'TAG':>8}  {'Type':>6}  {'Ref':>10}  {'Score':>10}  Result")
            print(f"  {'-' * 82}")

        for tid, score in scores_map.items():
            client_id = registry.get(tid, "Unknown")
            client_type = "MAL" if tid in mal_tags else "HON"
            best_ref_name = best_ref_map[tid]

            if tid in stage1_fail:
                if verbose_round:
                    print(f"  {client_id:>8}  {tid:>8}  {client_type:>6}  {best_ref_name:>10}  {score:>10.4f}  REJECT (Stage 1: Direction)")
                continue

            valid = True
            failed_stage = None

            ref_key = best_ref_name.split('+', 1)[0]
            bounds = ref_group_bounds.get(ref_key, default_bounds)
            min_acc = bounds['min_acc']
            max_acc = bounds['max_acc']

            if score < min_acc:
                valid = False
                failed_stage = f"Stage 2 (Too Small: {score:.4f} < {min_acc:.4f})"
            elif score > max_acc:
                valid = False
                failed_stage = f"Stage 2 (Too Large: {score:.4f} > {max_acc:.4f})"

            history_key = self._history_key(tid, best_ref_name)
            if valid:
                ok, reason = self._check_consistency(history_key, score, round_num)
                if not ok:
                    valid = False
                    failed_stage = f"Stage 3 (History: {reason})"

            if valid:
                if verbose_round:
                    print(f"  {client_id:>8}  {tid:>8}  {client_type:>6}  {best_ref_name:>10}  {score:>10.4f}  ACCEPT")
                accepted.add(tid)
                if history_key not in self.client_history:
                    self.client_history[history_key] = []
                self.client_history[history_key].append(score)
                if len(self.client_history[history_key]) > 10:
                    self.client_history[history_key].pop(0)
            else:
                if verbose_round:
                    print(f"  {client_id:>8}  {tid:>8}  {client_type:>6}  {best_ref_name:>10}  {score:>10.4f}  REJECT ({failed_stage})")

        acceptance_ratio = len(accepted) / len(tag_ids) if tag_ids else 1.0
        self.last_acceptance_ratio = acceptance_ratio
        self.empty_rounds = 0 if accepted else (self.empty_rounds + 1)
        self.last_reference_source = max(ref_usage, key=ref_usage.get)
        self.last_ref_usage = ref_usage
        self.last_stage1_pass_count = len(stage1_pass)
        self.last_stage1_fail_count = len(stage1_fail)
        self.last_round_size = len(tag_ids)
        positive_scores = np.array(list(stage1_pass.values()), dtype=float) if stage1_pass else np.array([], dtype=float)
        self.last_raw_median = raw_median
        self.last_positive_median = float(np.median(positive_scores)) if len(positive_scores) else direction_eps
        self.last_direction_eps = direction_eps

        if len(accepted) == 0 and verbose_round:
            print("  [Safety] No client accepted this round; aggregation skipped.")

        if verbose_round:
            print(f"  -> Accepted {len(accepted)}/{len(tag_ids)} clients")

        snapshot = self.update_table.copy()
        self.update_table = {}
        return {tid: {'count': 1, 'enc_data': snapshot[tid]} for tid in accepted}

    def feedback(self, global_grad):
        if global_grad is None:
            return

        survivor_ratio = self.last_stage1_pass_count / max(self.last_round_size, 1)
        min_survivors = max(4, int(np.ceil(0.4 * self.last_round_size)))
        healthy_round = (
            self.last_round_size > 0 and
            self.last_stage1_pass_count >= min_survivors and
            self.last_acceptance_ratio >= 0.35 and
            self.last_positive_median > max(self.last_direction_eps, 0.0)
        )

        if healthy_round:
            momentum = self.alpha_ref if self.last_acceptance_ratio > 0.7 else (0.90 if self.last_acceptance_ratio >= 0.45 else 0.95)
            new_ref = (momentum * self.ref_directions[0]) + ((1 - momentum) * global_grad)
            new_ref = self._normalize_reference(new_ref)
            self.ref_directions[0] = new_ref
            self.last_stable_ref = new_ref.copy()
            return

        recovery_target = self.last_stable_ref if self.last_stable_ref is not None else self.bootstrap_ref
        if self.collapse_streak >= 3:
            recovery_target = self.bootstrap_ref
        recovery_blend = 0.95 if self.collapse_streak < 3 else 0.99
        recovered_ref = (recovery_blend * recovery_target) + ((1.0 - recovery_blend) * self.ref_directions[0])
        self.ref_directions[0] = self._normalize_reference(recovered_ref)


# ============================================================
# CLIENT MANAGER
# ============================================================
class ClientManager:
    def __init__(self, auth, dm, dim):
        self.auth = auth
        self.dm = dm
        self.dim = dim
        self.clients_state_W = {}
        self.clients_state_b = {}
        self.client_configs = []

    def init_clients(self, n_clients, num_malicious):
        self.client_configs = []
        all_indices = list(range(n_clients))
        malicious_indices = np.random.choice(all_indices, num_malicious, replace=False)

        for i in range(n_clients):
            is_mal = (i in malicious_indices)
            c_id = f"C{i}"
            X, y = self.dm.get_client_data(i)
            self.client_configs.append({
                'id': c_id, 'X': X, 'y': y, 'mal': is_mal,
                'reg_tag': self.auth.register_user(c_id)
            })
            self.clients_state_W[c_id] = np.zeros((self.dim, 10))
            self.clients_state_b[c_id] = np.zeros(10)

        mal_ids = [f"C{i}" for i in malicious_indices]
        print(f"  Malicious clients: {sorted(mal_ids)}")

    def run_training_round(self, global_W, global_b):
        jobs = []
        pub, _ = self.auth.distribute_keys()
        for cfg in self.client_configs:
            self.clients_state_W[cfg['id']] = copy.deepcopy(global_W)
            self.clients_state_b[cfg['id']] = copy.deepcopy(global_b)
            args = (
                cfg['id'], cfg['X'], cfg['y'],
                self.clients_state_W[cfg['id']], self.clients_state_b[cfg['id']],
                cfg['mal'], 10, self.dim, pub, FIXED_POINT_SCALE,
                LEARNING_RATE, BATCH_SIZE, LOCAL_EPOCHS
            )
            jobs.append(args)

        with ProcessPoolExecutor(max_workers=NUM_CORES) as executor:
            results = list(executor.map(_train_client_worker, jobs))
        return results


# ============================================================
# SERVER
# ============================================================
class Server:
    def __init__(self, input_dim, num_classes=10):
        self.W = np.zeros((input_dim, num_classes))
        self.b = np.zeros(num_classes)
        self.input_dim = input_dim
        self.num_classes = num_classes
        self.fp = FixedPoint()

    def aggregate(self, packet, auth_priv):
        if not packet:
            return None

        first = list(packet.keys())[0]
        agg_enc = packet[first]['enc_data'][:]
        count = 1
        keys = list(packet.keys())
        for i in range(1, len(keys)):
            data = packet[keys[i]]['enc_data']
            for j in range(len(agg_enc)):
                agg_enc[j] = agg_enc[j] + data[j]
            count += 1

        flat_agg = self.fp.dec_vec(auth_priv, agg_enc)
        avg_update = flat_agg / count
        w_size = self.input_dim * self.num_classes
        update_W = avg_update[:w_size].reshape(self.input_dim, self.num_classes)
        update_b = avg_update[w_size:]
        self.W -= update_W
        self.b -= update_b
        return avg_update

    def evaluate_detailed(self, X_test, y_test):
        scores = np.dot(X_test, self.W) + self.b
        preds = np.argmax(scores, axis=1)
        acc = accuracy_score(y_test, preds)

        t_mask = y_test == 1
        t_acc = accuracy_score(y_test[t_mask], preds[t_mask]) if any(t_mask) else 0.0

        o_mask = (y_test != 1) & (y_test != 7)
        o_acc = accuracy_score(y_test[o_mask], preds[o_mask]) if any(o_mask) else 0.0

        return t_acc, o_acc, acc


def generate_accuracy_metric_plots(history, attack_rates, n_rounds):
    styles = ['-', '--', '-.', ':']
    rounds = np.arange(1, n_rounds + 1)
    plot_specs = [
        ('acc', 'Overall Accuracy Over Rounds', 'Accuracy', 'fip_iid_untargeted_overall_accuracy.png'),
        ('o_acc', 'Other-Class Accuracy Over Rounds', 'Other-Class Accuracy', 'fip_iid_untargeted_other_accuracy.png'),
        ('t_acc', 'Target Accuracy Over Rounds', 'Target Accuracy', 'fip_iid_untargeted_target_accuracy.png'),
    ]

    for metric_key, title, ylabel, filename in plot_specs:
        plt.figure(figsize=(10, 6))
        for i, ar in enumerate(attack_rates):
            mean_metric = np.mean(history[ar][metric_key], axis=0)
            plt.plot(rounds, mean_metric, linestyle=styles[i % len(styles)], linewidth=2,
                     label=f"AR = {ar * 100:.0f}%")

        plt.title(title)
        plt.xlabel('Communication Round')
        plt.ylabel(ylabel)
        plt.ylim([-0.05, 1.05])
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.savefig(filename, dpi=300)
        plt.show()
        plt.close()


# ============================================================
# MAIN
# ============================================================
if __name__ == '__main__':
    multiprocessing.set_start_method('spawn', force=True)

    history = {
        ar: {
            'acc': np.zeros((len(SEEDS), N_ROUNDS)),
            't_acc': np.zeros((len(SEEDS), N_ROUNDS)),
            'o_acc': np.zeros((len(SEEDS), N_ROUNDS)),
            'tpr': np.zeros((len(SEEDS), N_ROUNDS)),
            'fpr': np.zeros((len(SEEDS), N_ROUNDS)),
        } for ar in ATTACK_RATES
    }

    roc_data = {ar: {'y_true': [], 'y_score': []} for ar in ATTACK_RATES}
    all_round_results = []

    dm = DataManager(N_CLIENTS)
    dim = dm.get_input_shape()

    for seed_idx, seed in enumerate(SEEDS):
        print(f"\n{'=' * 60}")
        print(f" SEED: {seed}  ({seed_idx + 1}/{len(SEEDS)})")
        print(f"{'=' * 60}")

        np.random.seed(seed)

        for attack_rate in ATTACK_RATES:
            num_malicious = int(N_CLIENTS * attack_rate)
            print(f"\n{'=' * 60}")
            print(f" EXP: Attack Rate={attack_rate * 100:.0f}%  ({num_malicious} malicious)")
            print(f" Attack: Untargeted Label Flip (y+5)%10")
            print(f"{'=' * 60}")

            auth = TrustedKeyAuthority()
            verifier = FIPVerifier(auth, dm, dim, 10, attack_rate=attack_rate)
            server = Server(dim, 10)
            client_mgr = ClientManager(auth, dm, dim)
            client_mgr.init_clients(N_CLIENTS, num_malicious)

            X_test, y_test = dm.get_test_data()

            mal_tags = {c['reg_tag'] for c in client_mgr.client_configs if c['mal']}
            honest_tags = {c['reg_tag'] for c in client_mgr.client_configs if not c['mal']}

            actual_mal_ids = sorted([auth.registry[t] for t in mal_tags])
            print(f"\n  [Ground Truth] Malicious: {actual_mal_ids}")

            for r in range(N_ROUNDS):
                start_time = time.time()

                results = client_mgr.run_training_round(server.W, server.b)
                for res in results:
                    c_id, enc_grad, _ = res
                    tag = [c['reg_tag'] for c in client_mgr.client_configs if c['id'] == c_id][0]
                    verifier.receive_update(tag, enc_grad)

                packet = verifier.perform_fip_audit(round_num=r, mal_tags=mal_tags)

                if packet:
                    grad = server.aggregate(packet, auth.priv_key)
                    if grad is not None:
                        verifier.feedback(grad)

                t_acc, o_acc, acc = server.evaluate_detailed(X_test, y_test)
                history[attack_rate]['acc'][seed_idx, r] = acc
                history[attack_rate]['t_acc'][seed_idx, r] = t_acc
                history[attack_rate]['o_acc'][seed_idx, r] = o_acc

                accepted_tags = set(packet.keys()) if packet else set()
                rejected_tags = mal_tags.union(honest_tags) - accepted_tags

                TP = len(rejected_tags & mal_tags)
                FP = len(rejected_tags & honest_tags)
                tpr = TP / len(mal_tags) if len(mal_tags) > 0 else 1.0
                fpr = FP / len(honest_tags) if len(honest_tags) > 0 else 0.0

                history[attack_rate]['tpr'][seed_idx, r] = tpr
                history[attack_rate]['fpr'][seed_idx, r] = fpr

                TN = len(accepted_tags & honest_tags)
                all_round_results.append({
                    'Seed': seed,
                    'Attack_Rate': attack_rate,
                    'Round': r + 1,
                    'Acc': acc,
                    'Target_Acc': t_acc,
                    'Other_Acc': o_acc,
                    'TPR': tpr,
                    'FPR': fpr,
                    'Actual_Malicious_Detected': f"{TP}/{len(mal_tags)}",
                    'Actual_Honest_Detected': f"{TN}/{len(honest_tags)}",
                })

                dt = time.time() - start_time

                if (r + 1) % 10 == 0:
                    detected_ids = sorted([auth.registry[t] for t in rejected_tags])
                    accepted_ids = sorted([auth.registry[t] for t in accepted_tags])
                    true_positive_ids = sorted([auth.registry[t] for t in (rejected_tags & mal_tags)])
                    false_positive_ids = sorted([auth.registry[t] for t in (rejected_tags & honest_tags)])
                    print(f"\n  Round {r + 1:>3}: ACC={acc:.4f} | t_acc={t_acc:.4f} | "
                          f"o_acc={o_acc:.4f} | TPR={tpr:.2f} | FPR={fpr:.2f}")
                    print(f"    Actual Malicious   : {actual_mal_ids}")
                    print(f"    Detected Malicious : {detected_ids}")
                    print(f"    True Positives     : {true_positive_ids}")
                    print(f"    False Positives    : {false_positive_ids}")
                    print(f"    Accepted Clients   : {accepted_ids}")
                    print(f"    Rejected Clients   : {detected_ids}")
                    print(f"    Round Time         : {dt:.2f}s")

                if (r + 1) % 50 == 0:
                    print(f"  [Time] Round {r + 1} took {dt:.2f}s")

            roc_data[attack_rate]['y_true'].extend(verifier.roc_labels)
            roc_data[attack_rate]['y_score'].extend(verifier.roc_scores)

    df_all_rounds = pd.DataFrame(all_round_results)
    df_all_rounds.to_csv('final_fip_iid_untargeted_all_round_results.csv', index=False)
    print(f"[CSV] Saved {len(df_all_rounds)} rows to 'final_fip_iid_untargeted_all_round_results.csv'")

    generate_accuracy_metric_plots(history, ATTACK_RATES, N_ROUNDS)

    print("\n" + "=" * 60)
    print(" FINAL RESULTS ACROSS ALL SEEDS")
    print("=" * 60)
    for ar in ATTACK_RATES:
        final_accs = history[ar]['acc'][:, -1]
        final_t_accs = history[ar]['t_acc'][:, -1]
        print(f"\nAttack Rate {ar * 100:.0f}%:")
        print(f"  Overall Accuracy : {np.mean(final_accs):.4f} +/- {np.std(final_accs):.4f}")
        print(f"  Target Accuracy  : {np.mean(final_t_accs):.4f} +/- {np.std(final_t_accs):.4f}")

# %%
# Out:
# [System] Using REAL Paillier Encryption on 28 cores.
# [Setting] IID data distribution + Untargeted Label Flip (y+5)%10
# [Data] Downloading/Loading MNIST (70k samples)...
# [Data] Train=55000, Public=5000, Test=10000
# [Data] Distributing IID to 10 clients (all 10 classes each)...
#
# ============================================================
#  SEED: 123  (1/1)
# ============================================================
#
# ============================================================
#  EXP: Attack Rate=10%  (1 malicious)
#  Attack: Untargeted Label Flip (y+5)%10
# ============================================================
#   -> Generating 64-bit Paillier Keys...
# [System] Initializing FIP Verifier...
#   Malicious clients: ['C4']
#
#   [Ground Truth] Malicious: ['C4']
#
# [FIP] Round 10 | median=0.141208 | anchor=0.141940
#       dir_eps=0.000000 | global_bounds=(0.014194, 1.419396)
#       ratios=(0.10x, 10.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.1419
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.1430  ACCEPT
#         C1   TAG_002     HON      active      0.1403  ACCEPT
#         C2   TAG_003     HON      active      0.1399  ACCEPT
#         C3   TAG_004     HON      active      0.1436  ACCEPT
#         C4   TAG_005     MAL      active     -0.7826  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.1402  ACCEPT
#         C6   TAG_007     HON      active      0.1405  ACCEPT
#         C7   TAG_008     HON      active      0.1424  ACCEPT
#         C8   TAG_009     HON      active      0.1423  ACCEPT
#         C9   TAG_010     HON      active      0.1419  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  10: ACC=0.8648 | t_acc=0.9653 | o_acc=0.8473 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 282.50s
#
# [FIP] Round 20 | median=0.076011 | anchor=0.076184
#       dir_eps=0.000000 | global_bounds=(0.022855, 0.228552)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0762
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0768  ACCEPT
#         C1   TAG_002     HON      active      0.0748  ACCEPT
#         C2   TAG_003     HON      active      0.0754  ACCEPT
#         C3   TAG_004     HON      active      0.0777  ACCEPT
#         C4   TAG_005     MAL      active     -0.8664  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0758  ACCEPT
#         C6   TAG_007     HON      active      0.0756  ACCEPT
#         C7   TAG_008     HON      active      0.0774  ACCEPT
#         C8   TAG_009     HON      active      0.0765  ACCEPT
#         C9   TAG_010     HON      active      0.0762  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  20: ACC=0.8808 | t_acc=0.9698 | o_acc=0.8657 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 287.52s
#
# [FIP] Round 30 | median=0.053861 | anchor=0.053958
#       dir_eps=-0.000098 | global_bounds=(0.016187, 0.161874)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0540
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0542  ACCEPT
#         C1   TAG_002     HON      active      0.0521  ACCEPT
#         C2   TAG_003     HON      active      0.0538  ACCEPT
#         C3   TAG_004     HON      active      0.0551  ACCEPT
#         C4   TAG_005     MAL      active     -0.8822  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0531  ACCEPT
#         C6   TAG_007     HON      active      0.0537  ACCEPT
#         C7   TAG_008     HON      active      0.0552  ACCEPT
#         C8   TAG_009     HON      active      0.0553  ACCEPT
#         C9   TAG_010     HON      active      0.0540  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  30: ACC=0.8871 | t_acc=0.9716 | o_acc=0.8726 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 278.50s
#
# [FIP] Round 40 | median=0.042608 | anchor=0.042727
#       dir_eps=-0.000059 | global_bounds=(0.012818, 0.128181)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0427
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0429  ACCEPT
#         C1   TAG_002     HON      active      0.0407  ACCEPT
#         C2   TAG_003     HON      active      0.0427  ACCEPT
#         C3   TAG_004     HON      active      0.0433  ACCEPT
#         C4   TAG_005     MAL      active     -0.8800  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0419  ACCEPT
#         C6   TAG_007     HON      active      0.0425  ACCEPT
#         C7   TAG_008     HON      active      0.0432  ACCEPT
#         C8   TAG_009     HON      active      0.0432  ACCEPT
#         C9   TAG_010     HON      active      0.0420  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  40: ACC=0.8920 | t_acc=0.9724 | o_acc=0.8783 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 272.94s
#
# [FIP] Round 50 | median=0.035489 | anchor=0.035504
#       dir_eps=-0.000052 | global_bounds=(0.010651, 0.106511)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0355
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0355  ACCEPT
#         C1   TAG_002     HON      active      0.0334  ACCEPT
#         C2   TAG_003     HON      active      0.0357  ACCEPT
#         C3   TAG_004     HON      active      0.0360  ACCEPT
#         C4   TAG_005     MAL      active     -0.8726  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0352  ACCEPT
#         C6   TAG_007     HON      active      0.0355  ACCEPT
#         C7   TAG_008     HON      active      0.0361  ACCEPT
#         C8   TAG_009     HON      active      0.0365  ACCEPT
#         C9   TAG_010     HON      active      0.0350  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  50: ACC=0.8939 | t_acc=0.9724 | o_acc=0.8805 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 284.11s
#   [Time] Round 50 took 284.11s
#
# [FIP] Round 60 | median=0.030638 | anchor=0.030678
#       dir_eps=-0.000048 | global_bounds=(0.009203, 0.092033)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0307
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0306  ACCEPT
#         C1   TAG_002     HON      active      0.0285  ACCEPT
#         C2   TAG_003     HON      active      0.0309  ACCEPT
#         C3   TAG_004     HON      active      0.0308  ACCEPT
#         C4   TAG_005     MAL      active     -0.8623  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0303  ACCEPT
#         C6   TAG_007     HON      active      0.0307  ACCEPT
#         C7   TAG_008     HON      active      0.0312  ACCEPT
#         C8   TAG_009     HON      active      0.0316  ACCEPT
#         C9   TAG_010     HON      active      0.0300  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  60: ACC=0.8968 | t_acc=0.9724 | o_acc=0.8841 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 276.38s
#
# [FIP] Round 70 | median=0.027019 | anchor=0.027027
#       dir_eps=-0.000058 | global_bounds=(0.008108, 0.081080)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0270
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0270  ACCEPT
#         C1   TAG_002     HON      active      0.0250  ACCEPT
#         C2   TAG_003     HON      active      0.0274  ACCEPT
#         C3   TAG_004     HON      active      0.0278  ACCEPT
#         C4   TAG_005     MAL      active     -0.8509  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0268  ACCEPT
#         C6   TAG_007     HON      active      0.0270  ACCEPT
#         C7   TAG_008     HON      active      0.0282  ACCEPT
#         C8   TAG_009     HON      active      0.0281  ACCEPT
#         C9   TAG_010     HON      active      0.0268  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  70: ACC=0.8982 | t_acc=0.9733 | o_acc=0.8855 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 287.19s
#
# [FIP] Round 80 | median=0.024290 | anchor=0.024332
#       dir_eps=-0.000056 | global_bounds=(0.007300, 0.072996)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0243
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0242  ACCEPT
#         C1   TAG_002     HON      active      0.0224  ACCEPT
#         C2   TAG_003     HON      active      0.0250  ACCEPT
#         C3   TAG_004     HON      active      0.0247  ACCEPT
#         C4   TAG_005     MAL      active     -0.8394  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0243  ACCEPT
#         C6   TAG_007     HON      active      0.0242  ACCEPT
#         C7   TAG_008     HON      active      0.0252  ACCEPT
#         C8   TAG_009     HON      active      0.0255  ACCEPT
#         C9   TAG_010     HON      active      0.0241  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  80: ACC=0.9000 | t_acc=0.9733 | o_acc=0.8875 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 285.16s
#
# [FIP] Round 90 | median=0.022389 | anchor=0.022393
#       dir_eps=-0.000044 | global_bounds=(0.006718, 0.067180)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0224
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0224  ACCEPT
#         C1   TAG_002     HON      active      0.0204  ACCEPT
#         C2   TAG_003     HON      active      0.0230  ACCEPT
#         C3   TAG_004     HON      active      0.0227  ACCEPT
#         C4   TAG_005     MAL      active     -0.8266  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0223  ACCEPT
#         C6   TAG_007     HON      active      0.0224  ACCEPT
#         C7   TAG_008     HON      active      0.0230  ACCEPT
#         C8   TAG_009     HON      active      0.0235  ACCEPT
#         C9   TAG_010     HON      active      0.0221  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round  90: ACC=0.9018 | t_acc=0.9733 | o_acc=0.8900 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 283.99s
#
# [FIP] Round 100 | median=0.020490 | anchor=0.020497
#       dir_eps=-0.000067 | global_bounds=(0.006149, 0.061490)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0205
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0205  ACCEPT
#         C1   TAG_002     HON      active      0.0188  ACCEPT
#         C2   TAG_003     HON      active      0.0212  ACCEPT
#         C3   TAG_004     HON      active      0.0211  ACCEPT
#         C4   TAG_005     MAL      active     -0.8145  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0204  ACCEPT
#         C6   TAG_007     HON      active      0.0205  ACCEPT
#         C7   TAG_008     HON      active      0.0214  ACCEPT
#         C8   TAG_009     HON      active      0.0217  ACCEPT
#         C9   TAG_010     HON      active      0.0203  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 100: ACC=0.9033 | t_acc=0.9742 | o_acc=0.8915 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 283.06s
#   [Time] Round 100 took 283.06s
#
# [FIP] Round 110 | median=0.019144 | anchor=0.019185
#       dir_eps=-0.000038 | global_bounds=(0.005755, 0.057555)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0192
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0189  ACCEPT
#         C1   TAG_002     HON      active      0.0173  ACCEPT
#         C2   TAG_003     HON      active      0.0201  ACCEPT
#         C3   TAG_004     HON      active      0.0195  ACCEPT
#         C4   TAG_005     MAL      active     -0.8023  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0191  ACCEPT
#         C6   TAG_007     HON      active      0.0192  ACCEPT
#         C7   TAG_008     HON      active      0.0201  ACCEPT
#         C8   TAG_009     HON      active      0.0202  ACCEPT
#         C9   TAG_010     HON      active      0.0191  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 110: ACC=0.9045 | t_acc=0.9742 | o_acc=0.8928 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 288.70s
#
# [FIP] Round 120 | median=0.018075 | anchor=0.018157
#       dir_eps=-0.000030 | global_bounds=(0.005447, 0.054471)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0182
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0179  ACCEPT
#         C1   TAG_002     HON      active      0.0162  ACCEPT
#         C2   TAG_003     HON      active      0.0188  ACCEPT
#         C3   TAG_004     HON      active      0.0182  ACCEPT
#         C4   TAG_005     MAL      active     -0.7924  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0180  ACCEPT
#         C6   TAG_007     HON      active      0.0178  ACCEPT
#         C7   TAG_008     HON      active      0.0189  ACCEPT
#         C8   TAG_009     HON      active      0.0191  ACCEPT
#         C9   TAG_010     HON      active      0.0182  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 120: ACC=0.9048 | t_acc=0.9742 | o_acc=0.8931 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 276.38s
#
# [FIP] Round 130 | median=0.016942 | anchor=0.016952
#       dir_eps=-0.000037 | global_bounds=(0.005086, 0.050855)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0170
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0167  ACCEPT
#         C1   TAG_002     HON      active      0.0152  ACCEPT
#         C2   TAG_003     HON      active      0.0179  ACCEPT
#         C3   TAG_004     HON      active      0.0170  ACCEPT
#         C4   TAG_005     MAL      active     -0.7813  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0169  ACCEPT
#         C6   TAG_007     HON      active      0.0170  ACCEPT
#         C7   TAG_008     HON      active      0.0179  ACCEPT
#         C8   TAG_009     HON      active      0.0180  ACCEPT
#         C9   TAG_010     HON      active      0.0168  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 130: ACC=0.9060 | t_acc=0.9742 | o_acc=0.8945 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 278.31s
#
# [FIP] Round 140 | median=0.016062 | anchor=0.016087
#       dir_eps=-0.000036 | global_bounds=(0.004826, 0.048260)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0161
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0157  ACCEPT
#         C1   TAG_002     HON      active      0.0145  ACCEPT
#         C2   TAG_003     HON      active      0.0171  ACCEPT
#         C3   TAG_004     HON      active      0.0162  ACCEPT
#         C4   TAG_005     MAL      active     -0.7716  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0160  ACCEPT
#         C6   TAG_007     HON      active      0.0160  ACCEPT
#         C7   TAG_008     HON      active      0.0169  ACCEPT
#         C8   TAG_009     HON      active      0.0170  ACCEPT
#         C9   TAG_010     HON      active      0.0161  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 140: ACC=0.9071 | t_acc=0.9742 | o_acc=0.8958 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 282.02s
#
# [FIP] Round 150 | median=0.015288 | anchor=0.015386
#       dir_eps=-0.000034 | global_bounds=(0.004616, 0.046158)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0154
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0150  ACCEPT
#         C1   TAG_002     HON      active      0.0137  ACCEPT
#         C2   TAG_003     HON      active      0.0163  ACCEPT
#         C3   TAG_004     HON      active      0.0154  ACCEPT
#         C4   TAG_005     MAL      active     -0.7604  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0152  ACCEPT
#         C6   TAG_007     HON      active      0.0151  ACCEPT
#         C7   TAG_008     HON      active      0.0162  ACCEPT
#         C8   TAG_009     HON      active      0.0162  ACCEPT
#         C9   TAG_010     HON      active      0.0155  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 150: ACC=0.9082 | t_acc=0.9742 | o_acc=0.8972 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 285.01s
#   [Time] Round 150 took 285.01s
#
# [FIP] Round 160 | median=0.014575 | anchor=0.014612
#       dir_eps=-0.000038 | global_bounds=(0.004384, 0.043836)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0146
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0142  ACCEPT
#         C1   TAG_002     HON      active      0.0132  ACCEPT
#         C2   TAG_003     HON      active      0.0158  ACCEPT
#         C3   TAG_004     HON      active      0.0147  ACCEPT
#         C4   TAG_005     MAL      active     -0.7508  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0144  ACCEPT
#         C6   TAG_007     HON      active      0.0146  ACCEPT
#         C7   TAG_008     HON      active      0.0155  ACCEPT
#         C8   TAG_009     HON      active      0.0156  ACCEPT
#         C9   TAG_010     HON      active      0.0145  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 160: ACC=0.9085 | t_acc=0.9742 | o_acc=0.8976 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 290.21s
#
# [FIP] Round 170 | median=0.013910 | anchor=0.013932
#       dir_eps=-0.000037 | global_bounds=(0.004179, 0.041795)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0139
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0136  ACCEPT
#         C1   TAG_002     HON      active      0.0126  ACCEPT
#         C2   TAG_003     HON      active      0.0153  ACCEPT
#         C3   TAG_004     HON      active      0.0139  ACCEPT
#         C4   TAG_005     MAL      active     -0.7412  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0139  ACCEPT
#         C6   TAG_007     HON      active      0.0139  ACCEPT
#         C7   TAG_008     HON      active      0.0149  ACCEPT
#         C8   TAG_009     HON      active      0.0150  ACCEPT
#         C9   TAG_010     HON      active      0.0141  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 170: ACC=0.9092 | t_acc=0.9742 | o_acc=0.8983 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 290.06s
#
# [FIP] Round 180 | median=0.013500 | anchor=0.013589
#       dir_eps=-0.000036 | global_bounds=(0.004077, 0.040766)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:8, pub_2+rescue:1, pub_4+rescue:1
#       ref_anchors=active:0.0136, pub_2:0.0137, pub_4:0.0057
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0130  ACCEPT
#         C1   TAG_002     HON  pub_2+rescue      0.0137  ACCEPT
#         C2   TAG_003     HON      active      0.0148  ACCEPT
#         C3   TAG_004     HON  pub_4+rescue      0.0057  ACCEPT
#         C4   TAG_005     MAL      active     -0.7315  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0134  ACCEPT
#         C6   TAG_007     HON      active      0.0134  ACCEPT
#         C7   TAG_008     HON      active      0.0142  ACCEPT
#         C8   TAG_009     HON      active      0.0144  ACCEPT
#         C9   TAG_010     HON      active      0.0136  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 180: ACC=0.9107 | t_acc=0.9751 | o_acc=0.8998 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 286.07s
#
# [FIP] Round 190 | median=0.012847 | anchor=0.012922
#       dir_eps=-0.000055 | global_bounds=(0.003877, 0.038766)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:9, pub_4+rescue:1
#       ref_anchors=active:0.0130, pub_4:0.0034
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0125  ACCEPT
#         C1   TAG_002     HON      active      0.0116  ACCEPT
#         C2   TAG_003     HON      active      0.0141  ACCEPT
#         C3   TAG_004     HON  pub_4+rescue      0.0034  ACCEPT
#         C4   TAG_005     MAL      active     -0.7221  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0129  ACCEPT
#         C6   TAG_007     HON      active      0.0128  ACCEPT
#         C7   TAG_008     HON      active      0.0137  ACCEPT
#         C8   TAG_009     HON      active      0.0139  ACCEPT
#         C9   TAG_010     HON      active      0.0130  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 190: ACC=0.9108 | t_acc=0.9751 | o_acc=0.8998 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 284.11s
#
# [FIP] Round 200 | median=0.012293 | anchor=0.012297
#       dir_eps=-0.000059 | global_bounds=(0.003689, 0.036892)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:9, pub_4+rescue:1
#       ref_anchors=active:0.0125, pub_4:0.0047
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0121  ACCEPT
#         C1   TAG_002     HON      active      0.0111  ACCEPT
#         C2   TAG_003     HON      active      0.0138  ACCEPT
#         C3   TAG_004     HON  pub_4+rescue      0.0047  ACCEPT
#         C4   TAG_005     MAL      active     -0.7147  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0123  ACCEPT
#         C6   TAG_007     HON      active      0.0123  ACCEPT
#         C7   TAG_008     HON      active      0.0133  ACCEPT
#         C8   TAG_009     HON      active      0.0133  ACCEPT
#         C9   TAG_010     HON      active      0.0127  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 200: ACC=0.9118 | t_acc=0.9751 | o_acc=0.9009 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 286.51s
#   [Time] Round 200 took 286.51s
#
# [FIP] Round 210 | median=0.011834 | anchor=0.011908
#       dir_eps=-0.000060 | global_bounds=(0.003572, 0.035725)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:9, pub_4+rescue:1
#       ref_anchors=active:0.0120, pub_4:0.0029
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0115  ACCEPT
#         C1   TAG_002     HON      active      0.0108  ACCEPT
#         C2   TAG_003     HON      active      0.0134  ACCEPT
#         C3   TAG_004     HON  pub_4+rescue      0.0029  ACCEPT
#         C4   TAG_005     MAL      active     -0.7055  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0119  ACCEPT
#         C6   TAG_007     HON      active      0.0118  ACCEPT
#         C7   TAG_008     HON      active      0.0128  ACCEPT
#         C8   TAG_009     HON      active      0.0128  ACCEPT
#         C9   TAG_010     HON      active      0.0121  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 210: ACC=0.9123 | t_acc=0.9751 | o_acc=0.9014 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 283.16s
#
# [FIP] Round 220 | median=0.011578 | anchor=0.011585
#       dir_eps=-0.000035 | global_bounds=(0.003475, 0.034754)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:10
#       ref_anchors=active:0.0116
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0113  ACCEPT
#         C1   TAG_002     HON      active      0.0104  ACCEPT
#         C2   TAG_003     HON      active      0.0130  ACCEPT
#         C3   TAG_004     HON      active      0.0116  ACCEPT
#         C4   TAG_005     MAL      active     -0.6970  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0116  ACCEPT
#         C6   TAG_007     HON      active      0.0115  ACCEPT
#         C7   TAG_008     HON      active      0.0124  ACCEPT
#         C8   TAG_009     HON      active      0.0125  ACCEPT
#         C9   TAG_010     HON      active      0.0119  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 220: ACC=0.9124 | t_acc=0.9742 | o_acc=0.9016 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 282.44s
#
# [FIP] Round 230 | median=0.011080 | anchor=0.011082
#       dir_eps=-0.000042 | global_bounds=(0.003325, 0.033245)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:9, pub_4+rescue:1
#       ref_anchors=active:0.0111, pub_4:0.0069
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0109  ACCEPT
#         C1   TAG_002     HON      active      0.0100  ACCEPT
#         C2   TAG_003     HON  pub_4+rescue      0.0069  ACCEPT
#         C3   TAG_004     HON      active      0.0111  ACCEPT
#         C4   TAG_005     MAL      active     -0.6896  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0112  ACCEPT
#         C6   TAG_007     HON      active      0.0111  ACCEPT
#         C7   TAG_008     HON      active      0.0120  ACCEPT
#         C8   TAG_009     HON      active      0.0122  ACCEPT
#         C9   TAG_010     HON      active      0.0115  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 230: ACC=0.9130 | t_acc=0.9751 | o_acc=0.9020 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 291.13s
#
# [FIP] Round 240 | median=0.011110 | anchor=0.011135
#       dir_eps=-0.000038 | global_bounds=(0.003341, 0.033405)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:7, pub_0+rescue:2, pub_4+rescue:1
#       ref_anchors=pub_0:0.0119, active:0.0114, pub_4:0.0036
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_0+rescue      0.0128  ACCEPT
#         C1   TAG_002     HON  pub_0+rescue      0.0111  ACCEPT
#         C2   TAG_003     HON      active      0.0124  ACCEPT
#         C3   TAG_004     HON  pub_4+rescue      0.0036  ACCEPT
#         C4   TAG_005     MAL      active     -0.6825  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0110  ACCEPT
#         C6   TAG_007     HON      active      0.0107  ACCEPT
#         C7   TAG_008     HON      active      0.0117  ACCEPT
#         C8   TAG_009     HON      active      0.0118  ACCEPT
#         C9   TAG_010     HON      active      0.0111  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 240: ACC=0.9129 | t_acc=0.9751 | o_acc=0.9018 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 290.36s
#
# [FIP] Round 250 | median=0.010502 | anchor=0.010532
#       dir_eps=-0.000022 | global_bounds=(0.003160, 0.031596)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:9, pub_8+rescue:1
#       ref_anchors=active:0.0106, pub_8:0.0105
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0101  ACCEPT
#         C1   TAG_002     HON      active      0.0096  ACCEPT
#         C2   TAG_003     HON      active      0.0122  ACCEPT
#         C3   TAG_004     HON      active      0.0105  ACCEPT
#         C4   TAG_005     MAL      active     -0.6751  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0106  ACCEPT
#         C6   TAG_007     HON      active      0.0103  ACCEPT
#         C7   TAG_008     HON  pub_8+rescue      0.0105  ACCEPT
#         C8   TAG_009     HON      active      0.0115  ACCEPT
#         C9   TAG_010     HON      active      0.0109  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 250: ACC=0.9136 | t_acc=0.9751 | o_acc=0.9026 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 214.74s
#   [Time] Round 250 took 214.74s
#
# [FIP] Round 260 | median=0.010193 | anchor=0.010451
#       dir_eps=-0.000027 | global_bounds=(0.003135, 0.031353)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:8, pub_4+rescue:1, pub_6+rescue:1
#       ref_anchors=active:0.0106, pub_4:0.0026, pub_6:0.0099
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0099  ACCEPT
#         C1   TAG_002     HON      active      0.0094  ACCEPT
#         C2   TAG_003     HON      active      0.0118  ACCEPT
#         C3   TAG_004     HON  pub_4+rescue      0.0026  ACCEPT
#         C4   TAG_005     MAL      active     -0.6683  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0105  ACCEPT
#         C6   TAG_007     HON  pub_6+rescue      0.0099  ACCEPT
#         C7   TAG_008     HON      active      0.0111  ACCEPT
#         C8   TAG_009     HON      active      0.0111  ACCEPT
#         C9   TAG_010     HON      active      0.0106  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 260: ACC=0.9138 | t_acc=0.9751 | o_acc=0.9028 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 288.43s
#
# [FIP] Round 270 | median=0.009753 | anchor=0.009892
#       dir_eps=-0.000033 | global_bounds=(0.002968, 0.029676)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:7, pub_0+rescue:1, pub_4+rescue:2
#       ref_anchors=active:0.0101, pub_0:0.0086, pub_4:0.0054
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0096  ACCEPT
#         C1   TAG_002     HON  pub_0+rescue      0.0086  ACCEPT
#         C2   TAG_003     HON  pub_4+rescue      0.0055  ACCEPT
#         C3   TAG_004     HON  pub_4+rescue      0.0052  ACCEPT
#         C4   TAG_005     MAL      active     -0.6614  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0099  ACCEPT
#         C6   TAG_007     HON      active      0.0099  ACCEPT
#         C7   TAG_008     HON      active      0.0109  ACCEPT
#         C8   TAG_009     HON      active      0.0108  ACCEPT
#         C9   TAG_010     HON      active      0.0103  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 270: ACC=0.9139 | t_acc=0.9751 | o_acc=0.9030 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 285.19s
#
# [FIP] Round 280 | median=0.009622 | anchor=0.009696
#       dir_eps=-0.000023 | global_bounds=(0.002909, 0.029089)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:7, pub_0+rescue:1, pub_4+rescue:1, pub_8+rescue:1
#       ref_anchors=active:0.0099, pub_0:0.0102, pub_4:0.0031, pub_8:0.0069
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0094  ACCEPT
#         C1   TAG_002     HON  pub_0+rescue      0.0102  ACCEPT
#         C2   TAG_003     HON      active      0.0114  ACCEPT
#         C3   TAG_004     HON  pub_4+rescue      0.0031  ACCEPT
#         C4   TAG_005     MAL      active     -0.6547  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0097  ACCEPT
#         C6   TAG_007     HON      active      0.0095  ACCEPT
#         C7   TAG_008     HON  pub_8+rescue      0.0069  ACCEPT
#         C8   TAG_009     HON      active      0.0106  ACCEPT
#         C9   TAG_010     HON      active      0.0101  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 280: ACC=0.9144 | t_acc=0.9751 | o_acc=0.9035 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 288.52s
#
# [FIP] Round 290 | median=0.009453 | anchor=0.009588
#       dir_eps=-0.000026 | global_bounds=(0.002876, 0.028764)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:9, pub_4+rescue:1
#       ref_anchors=active:0.0097, pub_4:0.0023
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0091  ACCEPT
#         C1   TAG_002     HON      active      0.0086  ACCEPT
#         C2   TAG_003     HON      active      0.0113  ACCEPT
#         C3   TAG_004     HON  pub_4+rescue      0.0023  ACCEPT
#         C4   TAG_005     MAL      active     -0.6483  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0096  ACCEPT
#         C6   TAG_007     HON      active      0.0093  ACCEPT
#         C7   TAG_008     HON      active      0.0104  ACCEPT
#         C8   TAG_009     HON      active      0.0104  ACCEPT
#         C9   TAG_010     HON      active      0.0099  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 290: ACC=0.9148 | t_acc=0.9751 | o_acc=0.9040 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 288.60s
#
# [FIP] Round 300 | median=0.009188 | anchor=0.009312
#       dir_eps=-0.000023 | global_bounds=(0.002793, 0.027935)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=9 | stage1_fail=1 | ref_mix=active:8, pub_2+rescue:1, pub_4+rescue:1
#       ref_anchors=pub_2:0.0090, active:0.0097, pub_4:0.0018
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON  pub_2+rescue      0.0090  ACCEPT
#         C1   TAG_002     HON      active      0.0085  ACCEPT
#         C2   TAG_003     HON      active      0.0109  ACCEPT
#         C3   TAG_004     HON  pub_4+rescue      0.0018  ACCEPT
#         C4   TAG_005     MAL      active     -0.6413  REJECT (Stage 1: Direction)
#         C5   TAG_006     HON      active      0.0093  ACCEPT
#         C6   TAG_007     HON      active      0.0091  ACCEPT
#         C7   TAG_008     HON      active      0.0101  ACCEPT
#         C8   TAG_009     HON      active      0.0101  ACCEPT
#         C9   TAG_010     HON      active      0.0097  ACCEPT
#   -> Accepted 9/10 clients
#
#   Round 300: ACC=0.9149 | t_acc=0.9751 | o_acc=0.9040 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C4']
#     Detected Malicious : ['C4']
#     True Positives     : ['C4']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C3', 'C5', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C4']
#     Round Time         : 289.71s
#   [Time] Round 300 took 289.71s
#
# ============================================================
#  EXP: Attack Rate=20%  (2 malicious)
#  Attack: Untargeted Label Flip (y+5)%10
# ============================================================
#   -> Generating 64-bit Paillier Keys...
# [System] Initializing FIP Verifier...
#   Malicious clients: ['C3', 'C5']
#
#   [Ground Truth] Malicious: ['C3', 'C5']
#
# [FIP] Round 10 | median=0.141617 | anchor=0.142082
#       dir_eps=0.000000 | global_bounds=(0.014208, 1.420824)
#       ratios=(0.10x, 10.00x) | collapse_streak=0
#       stage1_pass=8 | stage1_fail=2 | ref_mix=active:10
#       ref_anchors=active:0.1421
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.1420  ACCEPT
#         C1   TAG_002     HON      active      0.1412  ACCEPT
#         C2   TAG_003     HON      active      0.1411  ACCEPT
#         C3   TAG_004     MAL      active     -0.8055  REJECT (Stage 1: Direction)
#         C4   TAG_005     HON      active      0.1429  ACCEPT
#         C5   TAG_006     MAL      active     -0.8056  REJECT (Stage 1: Direction)
#         C6   TAG_007     HON      active      0.1407  ACCEPT
#         C7   TAG_008     HON      active      0.1430  ACCEPT
#         C8   TAG_009     HON      active      0.1429  ACCEPT
#         C9   TAG_010     HON      active      0.1422  ACCEPT
#   -> Accepted 8/10 clients
#
#   Round  10: ACC=0.8650 | t_acc=0.9653 | o_acc=0.8474 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C3', 'C5']
#     Detected Malicious : ['C3', 'C5']
#     True Positives     : ['C3', 'C5']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C4', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C3', 'C5']
#     Round Time         : 286.77s
#
# [FIP] Round 20 | median=0.076073 | anchor=0.076348
#       dir_eps=0.000000 | global_bounds=(0.022904, 0.229043)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=8 | stage1_fail=2 | ref_mix=active:10
#       ref_anchors=active:0.0763
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0766  ACCEPT
#         C1   TAG_002     HON      active      0.0754  ACCEPT
#         C2   TAG_003     HON      active      0.0761  ACCEPT
#         C3   TAG_004     MAL      active     -0.8859  REJECT (Stage 1: Direction)
#         C4   TAG_005     HON      active      0.0767  ACCEPT
#         C5   TAG_006     MAL      active     -0.8917  REJECT (Stage 1: Direction)
#         C6   TAG_007     HON      active      0.0760  ACCEPT
#         C7   TAG_008     HON      active      0.0776  ACCEPT
#         C8   TAG_009     HON      active      0.0771  ACCEPT
#         C9   TAG_010     HON      active      0.0760  ACCEPT
#   -> Accepted 8/10 clients
#
#   Round  20: ACC=0.8802 | t_acc=0.9689 | o_acc=0.8649 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C3', 'C5']
#     Detected Malicious : ['C3', 'C5']
#     True Positives     : ['C3', 'C5']
#     False Positives    : []
#     Accepted Clients   : ['C0', 'C1', 'C2', 'C4', 'C6', 'C7', 'C8', 'C9']
#     Rejected Clients   : ['C3', 'C5']
#     Round Time         : 286.64s
#
# [FIP] Round 30 | median=0.053790 | anchor=0.053910
#       dir_eps=-0.000134 | global_bounds=(0.016173, 0.161729)
#       ratios=(0.30x, 3.00x) | collapse_streak=0
#       stage1_pass=8 | stage1_fail=2 | ref_mix=active:10
#       ref_anchors=active:0.0539
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     HON      active      0.0538  ACCEPT
#         C1   TAG_002     HON      active      0.0519  ACCEPT
#         C2   TAG_003     HON      active      0.0538  ACCEPT
#         C3   TAG_004     MAL      active     -0.9001  REJECT (Stage 1: Direction)
#         C4   TAG_005     HON      active      0.0551  ACCEPT
#         C5   TAG_006     MAL      active     -0.9063  REJECT (Stage 1: Direction)
#         C6   TAG_007     HON      active      0.0540  ACCEPT
#         C7   TAG_008     HON      active      0.0552  ACCEPT
#         C8   TAG_009     HON      active      0.0552  ACCEPT
#         C9   TAG_010     HON      active      0.0532  ACCEPT
#   -> Accepted 8/10 clients
#
#   Round  30: ACC=0.8881 | t_acc=0.9716 | o_acc=0.8737 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C3', 'C5']
#     Detected Malicious : ['C3', 'C5']
# ...
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL      active     -0.8881  REJECT (Stage 1: Direction)
#         C1   TAG_002     MAL      active     -0.8966  REJECT (Stage 1: Direction)
#         C2   TAG_003     HON      active      0.0099  ACCEPT
#         C3   TAG_004     HON      active      0.0103  ACCEPT
#         C4   TAG_005     HON      active      0.0107  ACCEPT
#         C5   TAG_006     MAL      active     -0.8974  REJECT (Stage 1: Direction)
#         C6   TAG_007     MAL      active     -0.8857  REJECT (Stage 1: Direction)
#         C7   TAG_008     HON      active      0.0108  ACCEPT
#         C8   TAG_009     MAL      active     -0.8928  REJECT (Stage 1: Direction)
#         C9   TAG_010     HON      active      0.0099  ACCEPT
#   -> Accepted 5/10 clients
#
#   Round 210: ACC=0.9107 | t_acc=0.9742 | o_acc=0.8994 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Detected Malicious : ['C0', 'C1', 'C5', 'C6', 'C8']
#     True Positives     : ['C0', 'C1', 'C5', 'C6', 'C8']
#     False Positives    : []
#     Accepted Clients   : ['C2', 'C3', 'C4', 'C7', 'C9']
#     Rejected Clients   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Round Time         : 205.72s
#
# [FIP] Round 220 | median=-0.436564 | anchor=0.010111
#       dir_eps=-0.010000 | global_bounds=(0.000506, 0.151664)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:10
#       ref_anchors=active:0.0101
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL      active     -0.8847  REJECT (Stage 1: Direction)
#         C1   TAG_002     MAL      active     -0.8939  REJECT (Stage 1: Direction)
#         C2   TAG_003     HON      active      0.0097  ACCEPT
#         C3   TAG_004     HON      active      0.0101  ACCEPT
#         C4   TAG_005     HON      active      0.0101  ACCEPT
#         C5   TAG_006     MAL      active     -0.8956  REJECT (Stage 1: Direction)
#         C6   TAG_007     MAL      active     -0.8828  REJECT (Stage 1: Direction)
#         C7   TAG_008     HON      active      0.0109  ACCEPT
#         C8   TAG_009     MAL      active     -0.8898  REJECT (Stage 1: Direction)
#         C9   TAG_010     HON      active      0.0098  ACCEPT
#   -> Accepted 5/10 clients
#
#   Round 220: ACC=0.9112 | t_acc=0.9742 | o_acc=0.8999 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Detected Malicious : ['C0', 'C1', 'C5', 'C6', 'C8']
#     True Positives     : ['C0', 'C1', 'C5', 'C6', 'C8']
#     False Positives    : []
#     Accepted Clients   : ['C2', 'C3', 'C4', 'C7', 'C9']
#     Rejected Clients   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Round Time         : 202.59s
#
# [FIP] Round 230 | median=-0.434979 | anchor=0.009615
#       dir_eps=-0.010000 | global_bounds=(0.000481, 0.144231)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:10
#       ref_anchors=active:0.0096
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL      active     -0.8820  REJECT (Stage 1: Direction)
#         C1   TAG_002     MAL      active     -0.8910  REJECT (Stage 1: Direction)
#         C2   TAG_003     HON      active      0.0095  ACCEPT
#         C3   TAG_004     HON      active      0.0096  ACCEPT
#         C4   TAG_005     HON      active      0.0098  ACCEPT
#         C5   TAG_006     MAL      active     -0.8913  REJECT (Stage 1: Direction)
#         C6   TAG_007     MAL      active     -0.8795  REJECT (Stage 1: Direction)
#         C7   TAG_008     HON      active      0.0104  ACCEPT
#         C8   TAG_009     MAL      active     -0.8838  REJECT (Stage 1: Direction)
#         C9   TAG_010     HON      active      0.0096  ACCEPT
#   -> Accepted 5/10 clients
#
#   Round 230: ACC=0.9118 | t_acc=0.9742 | o_acc=0.9004 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Detected Malicious : ['C0', 'C1', 'C5', 'C6', 'C8']
#     True Positives     : ['C0', 'C1', 'C5', 'C6', 'C8']
#     False Positives    : []
#     Accepted Clients   : ['C2', 'C3', 'C4', 'C7', 'C9']
#     Rejected Clients   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Round Time         : 203.52s
#
# [FIP] Round 240 | median=-0.432680 | anchor=0.009602
#       dir_eps=-0.010000 | global_bounds=(0.000480, 0.144034)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:10
#       ref_anchors=active:0.0096
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL      active     -0.8770  REJECT (Stage 1: Direction)
#         C1   TAG_002     MAL      active     -0.8874  REJECT (Stage 1: Direction)
#         C2   TAG_003     HON      active      0.0094  ACCEPT
#         C3   TAG_004     HON      active      0.0096  ACCEPT
#         C4   TAG_005     HON      active      0.0100  ACCEPT
#         C5   TAG_006     MAL      active     -0.8859  REJECT (Stage 1: Direction)
#         C6   TAG_007     MAL      active     -0.8747  REJECT (Stage 1: Direction)
#         C7   TAG_008     HON      active      0.0103  ACCEPT
#         C8   TAG_009     MAL      active     -0.8829  REJECT (Stage 1: Direction)
#         C9   TAG_010     HON      active      0.0095  ACCEPT
#   -> Accepted 5/10 clients
#
#   Round 240: ACC=0.9120 | t_acc=0.9742 | o_acc=0.9007 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Detected Malicious : ['C0', 'C1', 'C5', 'C6', 'C8']
#     True Positives     : ['C0', 'C1', 'C5', 'C6', 'C8']
#     False Positives    : []
#     Accepted Clients   : ['C2', 'C3', 'C4', 'C7', 'C9']
#     Rejected Clients   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Round Time         : 204.15s
#
# [FIP] Round 250 | median=-0.431856 | anchor=0.009334
#       dir_eps=-0.010000 | global_bounds=(0.000467, 0.140005)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:10
#       ref_anchors=active:0.0093
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL      active     -0.8748  REJECT (Stage 1: Direction)
#         C1   TAG_002     MAL      active     -0.8847  REJECT (Stage 1: Direction)
#         C2   TAG_003     HON      active      0.0093  ACCEPT
#         C3   TAG_004     HON      active      0.0091  ACCEPT
#         C4   TAG_005     HON      active      0.0095  ACCEPT
#         C5   TAG_006     MAL      active     -0.8835  REJECT (Stage 1: Direction)
#         C6   TAG_007     MAL      active     -0.8728  REJECT (Stage 1: Direction)
#         C7   TAG_008     HON      active      0.0095  ACCEPT
#         C8   TAG_009     MAL      active     -0.8789  REJECT (Stage 1: Direction)
#         C9   TAG_010     HON      active      0.0091  ACCEPT
#   -> Accepted 5/10 clients
#
#   Round 250: ACC=0.9121 | t_acc=0.9742 | o_acc=0.9008 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Detected Malicious : ['C0', 'C1', 'C5', 'C6', 'C8']
#     True Positives     : ['C0', 'C1', 'C5', 'C6', 'C8']
#     False Positives    : []
#     Accepted Clients   : ['C2', 'C3', 'C4', 'C7', 'C9']
#     Rejected Clients   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Round Time         : 205.26s
#   [Time] Round 250 took 205.26s
#
# [FIP] Round 260 | median=-0.429988 | anchor=0.008706
#       dir_eps=-0.005000 | global_bounds=(0.000435, 0.130595)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:10
#       ref_anchors=active:0.0087
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL      active     -0.8733  REJECT (Stage 1: Direction)
#         C1   TAG_002     MAL      active     -0.8797  REJECT (Stage 1: Direction)
#         C2   TAG_003     HON      active      0.0086  ACCEPT
#         C3   TAG_004     HON      active      0.0084  ACCEPT
#         C4   TAG_005     HON      active      0.0096  ACCEPT
#         C5   TAG_006     MAL      active     -0.8793  REJECT (Stage 1: Direction)
#         C6   TAG_007     MAL      active     -0.8684  REJECT (Stage 1: Direction)
#         C7   TAG_008     HON      active      0.0096  ACCEPT
#         C8   TAG_009     MAL      active     -0.8744  REJECT (Stage 1: Direction)
#         C9   TAG_010     HON      active      0.0087  ACCEPT
#   -> Accepted 5/10 clients
#
#   Round 260: ACC=0.9128 | t_acc=0.9742 | o_acc=0.9016 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Detected Malicious : ['C0', 'C1', 'C5', 'C6', 'C8']
#     True Positives     : ['C0', 'C1', 'C5', 'C6', 'C8']
#     False Positives    : []
#     Accepted Clients   : ['C2', 'C3', 'C4', 'C7', 'C9']
#     Rejected Clients   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Round Time         : 205.44s
#
# [FIP] Round 270 | median=-0.428503 | anchor=0.008855
#       dir_eps=-0.005000 | global_bounds=(0.000443, 0.132832)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:10
#       ref_anchors=active:0.0089
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL      active     -0.8657  REJECT (Stage 1: Direction)
#         C1   TAG_002     MAL      active     -0.8761  REJECT (Stage 1: Direction)
#         C2   TAG_003     HON      active      0.0089  ACCEPT
#         C3   TAG_004     HON      active      0.0087  ACCEPT
#         C4   TAG_005     HON      active      0.0091  ACCEPT
#         C5   TAG_006     MAL      active     -0.8775  REJECT (Stage 1: Direction)
#         C6   TAG_007     MAL      active     -0.8671  REJECT (Stage 1: Direction)
#         C7   TAG_008     HON      active      0.0093  ACCEPT
#         C8   TAG_009     MAL      active     -0.8731  REJECT (Stage 1: Direction)
#         C9   TAG_010     HON      active      0.0088  ACCEPT
#   -> Accepted 5/10 clients
#
#   Round 270: ACC=0.9131 | t_acc=0.9742 | o_acc=0.9020 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Detected Malicious : ['C0', 'C1', 'C5', 'C6', 'C8']
#     True Positives     : ['C0', 'C1', 'C5', 'C6', 'C8']
#     False Positives    : []
#     Accepted Clients   : ['C2', 'C3', 'C4', 'C7', 'C9']
#     Rejected Clients   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Round Time         : 202.95s
#
# [FIP] Round 280 | median=-0.426076 | anchor=0.008298
#       dir_eps=-0.005000 | global_bounds=(0.000415, 0.124470)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:10
#       ref_anchors=active:0.0083
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL      active     -0.8641  REJECT (Stage 1: Direction)
#         C1   TAG_002     MAL      active     -0.8719  REJECT (Stage 1: Direction)
#         C2   TAG_003     HON      active      0.0083  ACCEPT
#         C3   TAG_004     HON      active      0.0081  ACCEPT
#         C4   TAG_005     HON      active      0.0090  ACCEPT
#         C5   TAG_006     MAL      active     -0.8732  REJECT (Stage 1: Direction)
#         C6   TAG_007     MAL      active     -0.8600  REJECT (Stage 1: Direction)
#         C7   TAG_008     HON      active      0.0093  ACCEPT
#         C8   TAG_009     MAL      active     -0.8684  REJECT (Stage 1: Direction)
#         C9   TAG_010     HON      active      0.0078  ACCEPT
#   -> Accepted 5/10 clients
#
#   Round 280: ACC=0.9133 | t_acc=0.9742 | o_acc=0.9022 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Detected Malicious : ['C0', 'C1', 'C5', 'C6', 'C8']
#     True Positives     : ['C0', 'C1', 'C5', 'C6', 'C8']
#     False Positives    : []
#     Accepted Clients   : ['C2', 'C3', 'C4', 'C7', 'C9']
#     Rejected Clients   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Round Time         : 202.10s
#
# [FIP] Round 290 | median=-0.425679 | anchor=0.008203
#       dir_eps=-0.005000 | global_bounds=(0.000410, 0.123042)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:10
#       ref_anchors=active:0.0082
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL      active     -0.8599  REJECT (Stage 1: Direction)
#         C1   TAG_002     MAL      active     -0.8698  REJECT (Stage 1: Direction)
#         C2   TAG_003     HON      active      0.0082  ACCEPT
#         C3   TAG_004     HON      active      0.0079  ACCEPT
#         C4   TAG_005     HON      active      0.0087  ACCEPT
#         C5   TAG_006     MAL      active     -0.8700  REJECT (Stage 1: Direction)
#         C6   TAG_007     MAL      active     -0.8593  REJECT (Stage 1: Direction)
#         C7   TAG_008     HON      active      0.0090  ACCEPT
#         C8   TAG_009     MAL      active     -0.8646  REJECT (Stage 1: Direction)
#         C9   TAG_010     HON      active      0.0082  ACCEPT
#   -> Accepted 5/10 clients
#
#   Round 290: ACC=0.9132 | t_acc=0.9742 | o_acc=0.9021 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Detected Malicious : ['C0', 'C1', 'C5', 'C6', 'C8']
#     True Positives     : ['C0', 'C1', 'C5', 'C6', 'C8']
#     False Positives    : []
#     Accepted Clients   : ['C2', 'C3', 'C4', 'C7', 'C9']
#     Rejected Clients   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Round Time         : 201.10s
#
# [FIP] Round 300 | median=-0.424130 | anchor=0.008250
#       dir_eps=-0.005000 | global_bounds=(0.000413, 0.123756)
#       ratios=(0.05x, 15.00x) | collapse_streak=0
#       stage1_pass=5 | stage1_fail=5 | ref_mix=active:10
#       ref_anchors=active:0.0083
#     Client       TAG    Type         Ref       Score  Result
#   ----------------------------------------------------------------------------------
#         C0   TAG_001     MAL      active     -0.8562  REJECT (Stage 1: Direction)
#         C1   TAG_002     MAL      active     -0.8675  REJECT (Stage 1: Direction)
#         C2   TAG_003     HON      active      0.0083  ACCEPT
#         C3   TAG_004     HON      active      0.0080  ACCEPT
#         C4   TAG_005     HON      active      0.0086  ACCEPT
#         C5   TAG_006     MAL      active     -0.8666  REJECT (Stage 1: Direction)
#         C6   TAG_007     MAL      active     -0.8576  REJECT (Stage 1: Direction)
#         C7   TAG_008     HON      active      0.0090  ACCEPT
#         C8   TAG_009     MAL      active     -0.8626  REJECT (Stage 1: Direction)
#         C9   TAG_010     HON      active      0.0082  ACCEPT
#   -> Accepted 5/10 clients
#
#   Round 300: ACC=0.9132 | t_acc=0.9742 | o_acc=0.9022 | TPR=1.00 | FPR=0.00
#     Actual Malicious   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Detected Malicious : ['C0', 'C1', 'C5', 'C6', 'C8']
#     True Positives     : ['C0', 'C1', 'C5', 'C6', 'C8']
#     False Positives    : []
#     Accepted Clients   : ['C2', 'C3', 'C4', 'C7', 'C9']
#     Rejected Clients   : ['C0', 'C1', 'C5', 'C6', 'C8']
#     Round Time         : 205.30s
#   [Time] Round 300 took 205.30s
# [CSV] Saved 1200 rows to 'final_fip_iid_untargeted_all_round_results.csv'
# ============================================================
#  FINAL RESULTS ACROSS ALL SEEDS
# ============================================================
#
# Attack Rate 10%:
#   Overall Accuracy : 0.9149 +/- 0.0000
#   Target Accuracy  : 0.9751 +/- 0.0000
#
# Attack Rate 20%:
#   Overall Accuracy : 0.9150 +/- 0.0000
#   Target Accuracy  : 0.9751 +/- 0.0000
#
# Attack Rate 30%:
#   Overall Accuracy : 0.9133 +/- 0.0000
#   Target Accuracy  : 0.9742 +/- 0.0000
#
# Attack Rate 50%:
#   Overall Accuracy : 0.9132 +/- 0.0000
#   Target Accuracy  : 0.9742 +/- 0.0000
